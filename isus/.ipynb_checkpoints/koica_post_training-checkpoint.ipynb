# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#설문항목" data-toc-modified-id="설문항목-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>설문항목</a></span><ul class="toc-item"><li><span><a href="#교육-전-설문" data-toc-modified-id="교육-전-설문-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>교육 전 설문</a></span></li><li><span><a href="#교육-후-설문" data-toc-modified-id="교육-후-설문-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>교육 후 설문</a></span></li><li><span><a href="#설문분석" data-toc-modified-id="설문분석-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>설문분석</a></span><ul class="toc-item"><li><span><a href="#교육전-설문" data-toc-modified-id="교육전-설문-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>교육전 설문</a></span><ul class="toc-item"><li><span><a href="#연수생-선발/추천을-위한-사전준비-기간은-적절하였다" data-toc-modified-id="연수생-선발/추천을-위한-사전준비-기간은-적절하였다-1.3.1.1"><span class="toc-item-num">1.3.1.1&nbsp;&nbsp;</span>연수생 선발/추천을 위한 사전준비 기간은 적절하였다</a></span></li><li><span><a href="#연수-신청방법-및-교육내용에-대한-구체적인-안내를-받았다" data-toc-modified-id="연수-신청방법-및-교육내용에-대한-구체적인-안내를-받았다-1.3.1.2"><span class="toc-item-num">1.3.1.2&nbsp;&nbsp;</span>연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다</a></span></li></ul></li><li><span><a href="#교육후-설문" data-toc-modified-id="교육후-설문-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>교육후 설문</a></span><ul class="toc-item"><li><span><a href="#연수과정의-내용은-연수생-현지의-상황과-요구에-맞게-구성되었다." data-toc-modified-id="연수과정의-내용은-연수생-현지의-상황과-요구에-맞게-구성되었다.-1.3.2.1"><span class="toc-item-num">1.3.2.1&nbsp;&nbsp;</span>연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.</a></span></li><li><span><a href="#연수과정의-내용과-수준은-이해하기-적절하였다." data-toc-modified-id="연수과정의-내용과-수준은-이해하기-적절하였다.-1.3.2.2"><span class="toc-item-num">1.3.2.2&nbsp;&nbsp;</span>연수과정의 내용과 수준은 이해하기 적절하였다.</a></span></li><li><span><a href="#연수과정의-교육방법(강의,-실습/토의,-현장학습-등)은-연수내용을-이해하는데-적합하였다." data-toc-modified-id="연수과정의-교육방법(강의,-실습/토의,-현장학습-등)은-연수내용을-이해하는데-적합하였다.-1.3.2.3"><span class="toc-item-num">1.3.2.3&nbsp;&nbsp;</span>연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.</a></span></li><li><span><a href="#연수기관에서는-연수생-국가의-문화나-종교를-배려하기-위해-노력하였다" data-toc-modified-id="연수기관에서는-연수생-국가의-문화나-종교를-배려하기-위해-노력하였다-1.3.2.4"><span class="toc-item-num">1.3.2.4&nbsp;&nbsp;</span>연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다</a></span></li><li><span><a href="#연수운영진은-연수과정을-원활하게-운영하였다.-(일정관리,-강의준비,-연수생-지원-등)" data-toc-modified-id="연수운영진은-연수과정을-원활하게-운영하였다.-(일정관리,-강의준비,-연수생-지원-등)-1.3.2.5"><span class="toc-item-num">1.3.2.5&nbsp;&nbsp;</span>연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)</a></span></li><li><span><a href="#연수운영진은-응급상황-등-사건사고에-대해-적절히-대처하였다." data-toc-modified-id="연수운영진은-응급상황-등-사건사고에-대해-적절히-대처하였다.-1.3.2.6"><span class="toc-item-num">1.3.2.6&nbsp;&nbsp;</span>연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.</a></span></li><li><span><a href="#강의실-및-실습실은-사용하기에-편리하였다." data-toc-modified-id="강의실-및-실습실은-사용하기에-편리하였다.-1.3.2.7"><span class="toc-item-num">1.3.2.7&nbsp;&nbsp;</span>강의실 및 실습실은 사용하기에 편리하였다.</a></span></li><li><span><a href="#연수-편의시설(휴게시설,-식당,-숙박시설-등)은-사용하기에-편리하였다." data-toc-modified-id="연수-편의시설(휴게시설,-식당,-숙박시설-등)은-사용하기에-편리하였다.-1.3.2.8"><span class="toc-item-num">1.3.2.8&nbsp;&nbsp;</span>연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다.</a></span></li><li><span><a href="#연수과정에-사용된-교수학습매체는-적절하였다.-(교재,-동영상,-실습장비-등)" data-toc-modified-id="연수과정에-사용된-교수학습매체는-적절하였다.-(교재,-동영상,-실습장비-등)-1.3.2.9"><span class="toc-item-num">1.3.2.9&nbsp;&nbsp;</span>연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)</a></span></li><li><span><a href="#강사진은-해당-분야에-대한-실무경험이나-전문성-수준이-높은-인력으로-구성되었다." data-toc-modified-id="강사진은-해당-분야에-대한-실무경험이나-전문성-수준이-높은-인력으로-구성되었다.-1.3.2.10"><span class="toc-item-num">1.3.2.10&nbsp;&nbsp;</span>강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.</a></span></li><li><span><a href="#강사는-연수생과-소통하며-교육내용을-체계적이고-능숙하게-전달하였다" data-toc-modified-id="강사는-연수생과-소통하며-교육내용을-체계적이고-능숙하게-전달하였다-1.3.2.11"><span class="toc-item-num">1.3.2.11&nbsp;&nbsp;</span>강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다</a></span></li><li><span><a href="#통역사는-이해하기-쉽도록-통역하였다." data-toc-modified-id="통역사는-이해하기-쉽도록-통역하였다.-1.3.2.12"><span class="toc-item-num">1.3.2.12&nbsp;&nbsp;</span>통역사는 이해하기 쉽도록 통역하였다.</a></span></li><li><span><a href="#국별보고/액션플랜의-주제는-연수과정-목표와-연계되어-있었다." data-toc-modified-id="국별보고/액션플랜의-주제는-연수과정-목표와-연계되어-있었다.-1.3.2.13"><span class="toc-item-num">1.3.2.13&nbsp;&nbsp;</span>국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.</a></span></li><li><span><a href="#국별보고/액션플랜-세션시간은-충분하였다." data-toc-modified-id="국별보고/액션플랜-세션시간은-충분하였다.-1.3.2.14"><span class="toc-item-num">1.3.2.14&nbsp;&nbsp;</span>국별보고/액션플랜 세션시간은 충분하였다.</a></span></li><li><span><a href="#액션플랜-작성-및-발표를-위한-사전안내가-충분히-이루어졌다." data-toc-modified-id="액션플랜-작성-및-발표를-위한-사전안내가-충분히-이루어졌다.-1.3.2.15"><span class="toc-item-num">1.3.2.15&nbsp;&nbsp;</span>액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.</a></span></li><li><span><a href="#국별보고/액션플랜-세션-담당자는-피드백을-충분히-제공하였다." data-toc-modified-id="국별보고/액션플랜-세션-담당자는-피드백을-충분히-제공하였다.-1.3.2.16"><span class="toc-item-num">1.3.2.16&nbsp;&nbsp;</span>국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.</a></span></li><li><span><a href="#국별보고/액션플랜-세션은-연수내용을-이해하는데-도움이-되었다." data-toc-modified-id="국별보고/액션플랜-세션은-연수내용을-이해하는데-도움이-되었다.-1.3.2.17"><span class="toc-item-num">1.3.2.17&nbsp;&nbsp;</span>국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.</a></span></li><li><span><a href="#액션플랜-작성은-현장에서-실무능력을-향상시키는데-도움이-되었다." data-toc-modified-id="액션플랜-작성은-현장에서-실무능력을-향상시키는데-도움이-되었다.-1.3.2.18"><span class="toc-item-num">1.3.2.18&nbsp;&nbsp;</span>액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.</a></span></li></ul></li></ul></li><li><span><a href="#교육전후-교과별-'인지-수준---기술-수준---태도-수준'-변화-분석" data-toc-modified-id="교육전후-교과별-'인지-수준---기술-수준---태도-수준'-변화-분석-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>교육전후 교과별 '인지 수준 - 기술 수준 - 태도 수준' 변화 분석</a></span><ul class="toc-item"><li><span><a href="#'PPP와-개도국에-대한-PPP적용방법에-대한-이해-(A교과)'에-대한-참가자별-'인지---기술---태도'-수준-변화" data-toc-modified-id="'PPP와-개도국에-대한-PPP적용방법에-대한-이해-(A교과)'에-대한-참가자별-'인지---기술---태도'-수준-변화-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>'PPP와 개도국에 대한 PPP적용방법에 대한 이해 (A교과)'에 대한 참가자별 '인지 - 기술 - 태도' 수준 변화</a></span><ul class="toc-item"><li><span><a href="#A교과에-대한-인지-수준-변화" data-toc-modified-id="A교과에-대한-인지-수준-변화-1.4.1.1"><span class="toc-item-num">1.4.1.1&nbsp;&nbsp;</span>A교과에 대한 인지 수준 변화</a></span></li><li><span><a href="#A교과에-대한-기술-수준-변화" data-toc-modified-id="A교과에-대한-기술-수준-변화-1.4.1.2"><span class="toc-item-num">1.4.1.2&nbsp;&nbsp;</span>A교과에 대한 기술 수준 변화</a></span></li><li><span><a href="#A교과에-대한-태도-수준-변화" data-toc-modified-id="A교과에-대한-태도-수준-변화-1.4.1.3"><span class="toc-item-num">1.4.1.3&nbsp;&nbsp;</span>A교과에 대한 태도 수준 변화</a></span></li></ul></li><li><span><a href="#'개도국을-위한-적용가능한-수질개선기술-(B교과)'에-대한-참가자별-'인지---기술---태도'-수준-변화" data-toc-modified-id="'개도국을-위한-적용가능한-수질개선기술-(B교과)'에-대한-참가자별-'인지---기술---태도'-수준-변화-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>'개도국을 위한 적용가능한 수질개선기술 (B교과)'에 대한 참가자별 '인지 - 기술 - 태도' 수준 변화</a></span><ul class="toc-item"><li><span><a href="#B교과에-대한-인지-수준-변화" data-toc-modified-id="B교과에-대한-인지-수준-변화-1.4.2.1"><span class="toc-item-num">1.4.2.1&nbsp;&nbsp;</span>B교과에 대한 인지 수준 변화</a></span></li><li><span><a href="#B교과에-대한-기술-수준-변화" data-toc-modified-id="B교과에-대한-기술-수준-변화-1.4.2.2"><span class="toc-item-num">1.4.2.2&nbsp;&nbsp;</span>B교과에 대한 기술 수준 변화</a></span></li><li><span><a href="#B교과에-대한-태도-수준-변화" data-toc-modified-id="B교과에-대한-태도-수준-변화-1.4.2.3"><span class="toc-item-num">1.4.2.3&nbsp;&nbsp;</span>B교과에 대한 태도 수준 변화</a></span></li></ul></li><li><span><a href="#'개도국을-위한-미디어시티,-도로,-교통시설-개발-(C-교과)'-에-대한-참가자별-'인지---기술---태도'-수준-변화" data-toc-modified-id="'개도국을-위한-미디어시티,-도로,-교통시설-개발-(C-교과)'-에-대한-참가자별-'인지---기술---태도'-수준-변화-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>'개도국을 위한 미디어시티, 도로, 교통시설 개발 (C 교과)' 에 대한 참가자별 '인지 - 기술 - 태도' 수준 변화</a></span><ul class="toc-item"><li><span><a href="#C교과에-대한-인지-수준-변화" data-toc-modified-id="C교과에-대한-인지-수준-변화-1.4.3.1"><span class="toc-item-num">1.4.3.1&nbsp;&nbsp;</span>C교과에 대한 인지 수준 변화</a></span></li><li><span><a href="#C교과에-대한-기술-수준-변화" data-toc-modified-id="C교과에-대한-기술-수준-변화-1.4.3.2"><span class="toc-item-num">1.4.3.2&nbsp;&nbsp;</span>C교과에 대한 기술 수준 변화</a></span></li><li><span><a href="#C교과에-대한-태도-수준-변화" data-toc-modified-id="C교과에-대한-태도-수준-변화-1.4.3.3"><span class="toc-item-num">1.4.3.3&nbsp;&nbsp;</span>C교과에 대한 태도 수준 변화</a></span></li></ul></li><li><span><a href="#교육전후-교과별-'인지-수준---기술-수준---태도-수준'-변화의-합" data-toc-modified-id="교육전후-교과별-'인지-수준---기술-수준---태도-수준'-변화의-합-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>교육전후 교과별 '인지 수준 - 기술 수준 - 태도 수준' 변화의 합</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # 설문항목
#
# ## 교육 전 설문
# **1. The following questions relate to the guide for the application and participant selection for the course. Please check the number that best expresses your thoughts.  (다음은 귀하께서 참여하신 연수과정의 운영 적절성 및 만족도에 대한 항목입니다. 각 문항에 대해 귀하의 생각과 일치하시는 곳에 ✔표 하여 주시길 바랍니다.)**<br><br>
#
#    *Check: ① Strongly disagree  (전혀 그렇지않다) ② Disagree  (그렇지않다) ③ Neutral  (보통이다) ④ Agree  (그렇다) ⑤ Strongly agree  (매우 그렇다)* <br><br>
#
#    1-1. Preparatory period for applying and selecting participants was appropriate.  (연수생 선발/추천을 위한 사전준비 기간은
# 적절하였다.)<br>
#    1-2. I received a detailed guide on how to apply for a program and the content of the program.  (연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.)<br><br>
#
#
# **2. The following questions relate to the level of prior knowledge as to the main learning content of the course.  (다음은 귀하께서 참여하신 연수과정의 주요 학습내용에 대한 선행수준에 대한 문항입니다.)**<br><br>
# Please check the number that matches your current level of learning content below  (아래 학습내용에 대한 귀하의 현재수준과 일치하시는 곳에 ✔표 하여 주시길 바랍니다.): <br>
#    2-1. Understanding Public-Private Partnership and Its Applicability to Developing Countries)  (PPP와 개도국에 대한 PPP적용방법에 대한 이해) <br>
#    2-2. Applicable Water Quality Improvement Technique for Developing Countries  (개도국을 위한 적용가능한 수질개선기술) <br>
#    2-3. Developing a Media City and Road and Traffic Facility for Developing Countries  (개도국을 위한 미디어시티, 도로, 교통시설 개발) <br><br>
#
#    *Check: 2-1-1 / 2-2-1 / 2-3-1. Cognitive knowledge  (인지 수준)* <br>
#     ① I do not know the basic theory or knowledge about learning content.  (학습내용과 관련된 기초이론이나 지식을 알지 못한다.) <br>
#     ② I have basic knowledge about learning content.  (학습내용에 대한 기초적인 지식을 가지고 있다.) <br>
#     ③ I can explain learning content to others.  (학습내용에 대해 다른 사람에게 설명할 수 있다.) <br>
#     ④ I can apply learning content to similar tasks.  (학습내용을 유사한 업무에 적용할 수 있다.) <br>
#     ⑤ I can apply learning content to other tasks as well as similar tasks.  (학습내용을 유사한 업무뿐만 아니라 다른 상황에도 응용할 수 있다.) <br><br>
#
#    *Check: 2-1-2 / 2-2-2 / 2-3-2. Technical skill*  (기술 수준) <br>
#     ① I do not know the procedure or method for carrying out learning content.  (학습내용을 실행하기 위한 절차나 방법을 모른다.) <br>
#     ② I am familiar with the procedure and method of using learning content for work.  (학습내용을 업무에 활용하는 절차나 방법을 알고 있다.) <br>
#     ③ I can use learning content for work under the guidance of others.  (학습내용을 다른 사람의 지도를 받아 업무에 활용할 수 있다.) <br>
#     ④ I can use learning content for work without help of others.  (학습내용을 다른 사람의 도움 없이 스스로 업무에 활용할 수 있다.) <br>
#     ⑤ I can use learning content for work to produce successful outcomes.  (학습내용을 업무에 활용하여 성공적인 결과를 낼 수 있다.) <br><br>
#
#    *Check: 2-1-3 / 2-2-3 / 2-3-3. Attitude*  (태도 수준) <br>
#     ① I am not interested in learning content.  (학습내용에 관심이 없다.) <br>
#     ② I am interested in learning content.  (학습내용에 관심이나 흥미가 있다.) <br>
#     ③ I think learning content is important and valuable to me.  (학습내용은 나에게 중요하고 가치 있는 내용이라고 생각한다.) <br>
#     ④ I am willing to strive to apply learning content to work.  (학습내용을 업무에 적용하기 위해 노력할 마음이 있다.) <br>
#     ⑤ I have a concrete plan to apply learning content to work.  (학습내용을 업무에 적용할 구체적인 계획이 있다.) <br><br>

# %% [markdown]
# ## 교육 후 설문
# **1. The following questions relate to the level of satisfaction in program content, operation and facilities. Please check the number that best expresses your thoughts.**<br><br>
#
#    *Check: ① Very unsatisfactory (매우 불만족) ② Unsatisfactory (불만족) ③ Neutral (보통) ④ Satisfactory (만족) ⑤ Very satisfactory (매우 만족)* <br>
#
#    **Program Content (연수프로그램)**<br>
#    1-1. The content of the course was tailored to the circumstances and needs of the participants’ country. (연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.) <br>
#    1-2. The content and level of the course were appropriate to understand. (연수과정의 내용과 수준은 이해하기 적절하였다.)<br>
#    1-3. The education methods of the course  (lecture, practice/ discussion, field learning, etc.) were appropriate to understand the content. (연수과정의 교육방법 (강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.)<br>
#
#    **Program Operation (연수운영)**<br>
#    1-4. The training institute tried to consider the culture and religion of the participants’country. (연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다.) <br>
#    1-5. The staff managed the program process smoothly  (schedule management, lecture preparation, support for participants, etc.). (연수운영진은 연수과정을 원활하게 운영하였다.  (일정관리, 강의준비, 연수생 지원 등))<br>
#    1-6. The staff responded properly to accidents such as emergency  situations. (연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.)<br>
#
#    **Program Facilities (연수시설)**<br>
#    1-7. Classrooms and laboratories were convenient to use. (강의실 및 실습실은 사용하기에 편리하였다.) <br>
#    1-8. Program amenities  (rest lounges, restaurants, accommodations, etc.) were convenient to use. (연수 편의시설 (휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다.) <br>
#
# **2. The following questions relate to the level of satisfaction about the materials and instructors. (다음은 귀하께서 참여하신 연수과정의 교재 및 강사 만족도에 대한 항목입니다.)**<br><br>
#    *Check: ① There was an interpreter. (통역이 있었음) ② There was no interpreter. (통역이 없었음)*<br>
#    2-1. Was there any interpreter in the course that you attended? (귀하께서 참여하신 연수과정에 통역사가 있었습니까?) <br><br>
#
#    *Check: ① Very unsatisfactory (매우 불만족) ② Unsatisfactory (불만족) ③ Neutral (보통) ④ Satisfactory (만족) ⑤ Very satisfactory (매우 만족)* <br>
#    2-2. Please check the number that best expresses your thoughts. (각 문항에 대해 귀하의 생각과 일치하시는 곳에 ✔표 하여 주시길 바랍니다.) <br><br>
#    2-2-1. The teaching and learning medium used in the course was appropriate  (eg. materials, videos, practice equipment, etc.). (연수과정에 사용된 교수학습매체는 적절하였다.  (교재, 동영상, 실습장비 등))<br>
#    2-2-2. Instructors consisted of those with a high level of practical experience and expertise in the field. (강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.)<br>
#    2-2-3. Instructors communicated with participants to deliver the training content in a systematic, proficient manner. (강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다)<br>
#    2-2-4. Interpreting was easy to understand  (If you answered ② in 2-1, you do not have to answer). (통역사는 이해하기 쉽도록 통역하였다.  (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다))<br><br>
#
# **3. The following questions relate to the level of accomplishment with respect to the main learning content. (다음은 귀하께서 참여하신 연수과정의 주요 학습내용에 대한 성취수준에 대한 문항입니다.)**<br><br>
# Please check the number that matches your current level of learning content below (아래 학습내용에 대한 귀하의 현재수준과 일치하시는 곳에 ✔표 하여 주시길 바랍니다.): <br>
#    3-1. Understanding Public-Private Partnership and Its Applicability to Developing Countries) (PPP와 개도국에 대한 PPP적용방법에 대한 이해) <br>
#    3-2. Applicable Water Quality Improvement Technique for Developing Countries (개도국을 위한 적용가능한 수질개선기술) <br>
#    3-3. Developing a Media City and Road and Traffic Facility for Developing Countries (개도국을 위한 미디어시티, 도로, 교통시설 개발) <br><br>
#
#    *Check: 3-1-1 / 3-2-1 / 3-3-1. Cognitive knowledge (인지 수준)* <br>
#     ① I do not know the basic theory or knowledge about learning content. (학습내용과 관련된 기초이론이나 지식을 알지 못한다.) <br>
#     ② I have basic knowledge about learning content. (학습내용에 대한 기초적인 지식을 가지고 있다.) <br>
#     ③ I can explain learning content to others. (학습내용에 대해 다른 사람에게 설명할 수 있다.) <br>
#     ④ I can apply learning content to similar tasks. (학습내용을 유사한 업무에 적용할 수 있다.) <br>
#     ⑤ I can apply learning content to other tasks as well as similar tasks. (학습내용을 유사한 업무뿐만 아니라 다른 상황에도 응용할 수 있다.) <br><br>
#
#    *Check: 3-1-2 / 3-2-2 / 3-3-2. Technical skill* (기술 수준) <br>
#     ① I do not know the procedure or method for carrying out learning content. (학습내용을 실행하기 위한 절차나 방법을 모른다.) <br>
#     ② I am familiar with the procedure and method of using learning content for work. (학습내용을 업무에 활용하는 절차나 방법을 알고 있다.) <br>
#     ③ I can use learning content for work under the guidance of others. (학습내용을 다른 사람의 지도를 받아 업무에 활용할 수 있다.) <br>
#     ④ I can use learning content for work without help of others. (학습내용을 다른 사람의 도움 없이 스스로 업무에 활용할 수 있다.) <br>
#     ⑤ I can use learning content for work to produce successful outcomes. (학습내용을 업무에 활용하여 성공적인 결과를 낼 수 있다.) <br><br>
#
#    *Check: 3-1-3 / 3-2-3 / 3-3-3. Attitude* (태도 수준) <br>
#     ① I am not interested in learning content. (학습내용에 관심이 없다.) <br>
#     ② I am interested in learning content. (학습내용에 관심이나 흥미가 있다.) <br>
#     ③ I think learning content is important and valuable to me. (학습내용은 나에게 중요하고 가치 있는 내용이라고 생각한다.) <br>
#     ④ I am willing to strive to apply learning content to work. (학습내용을 업무에 적용하기 위해 노력할 마음이 있다.) <br>
#     ⑤ I have a concrete plan to apply learning content to work. (학습내용을 업무에 적용할 구체적인 계획이 있다.) <br><br>

# %% [markdown]
# * 교과목명 index
#     * A교과: Understanding Public-Private Partnership and Its Applicability to Developing Countries (PPP와 개도국에 대한 PPP적용방법에 대한 이해)
#     * B교과: Applicable Water Quality Improvement Technique for Developing Countries (개도국을 위한 적용가능한 수질개선기술)
#     * C교과: Developing a Media City and Road and Traffic Facility for Developing Countries (개도국을 위한 미디어시티, 도로, 교통시설 개발)

# %% [markdown]
# # 강의평가 설문
#
# 아래 질문 별로 5점 척도 중 해당되는 체크항목에 표시 <br><br>
# Check: ① Strongly disagree (전혀 그렇지않다) ② Disagree (그렇지않다) ③ Neutral (보통이다) ④ Agree (그렇다) ⑤ Strongly agree (매우 그렇다)
#
# 1. The lecture was relevant to the training objectives. (연수 목표와의 연관성)
# 2. The lecturer was knowledgeable. (강사 전문성)
# 3. The material was useful. (강의교재)
# 4. The lecturer's English proficiency (translation skill) was good enough. (강사 영어구사력 (또는 통역 숙련도))
# 5. Class participation and interaction were encouraged. (참여도 제고)
# 6. Adequate time was allocated for the lecture. (강의시간 적절성)

# %% [markdown]
# * 강의명 index
#     * 강의1: 국제협력 사업실행팀 수자원개발 및 관리사례
#     * 강의2: 국제협력 사업실행팀 수처리시설건설사례 세미나
#     * 강의3: 민간투자사업제도와 적격성조사
#     * 강의4: 도로교통시설과 도로정책
#     * 강의5: 한국의 공공투자관리시스템
#     * 강의6: 상암미디어시티 개발사례
#     * 강의7: 국제협력사업실습

# %%
# %matplotlib nbagg

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = [10, 6]


# #  display two pandas tables side by side
# from IPython.display import display, HTML
# CSS = """
# .output {
#     flex-direction: row;
# }
# """
# HTML('<style>{}</style>'.format(CSS))


# 기본 글꼴 변경
import matplotlib as mpl
mpl.font_manager._rebuild()
mpl.pyplot.rc('font', family='NanumBarunGothic')

# allow multiple outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
murd_fl= pd.read_excel("C:/Users/Gumin JUNG/isus/Raw Data_시립대 국토개발정책 사후관리_성철수정-분석용v1.3.xlsx",
                       sheet_name='만족도_raw data', index_col='성명', header=3)
murd_fl_crs_eval= pd.read_excel("C:/Users/Gumin JUNG/isus/Raw Data_시립대 국토개발정책 사후관리_성철수정-분석용v1.3.xlsx",
                                sheet_name='강의평가_raw data',index_col='성명', header=2) # skiprows = [13,14]
murd_fl_crs_eval = murd_fl_crs_eval.iloc[0:13]
murd_info = pd.read_excel("C:/Users/Gumin JUNG/Desktop/IUDP학생현황.xlsx", sheet_name='IUDPStuInfo',
                         index_col='성명')

# %%
# 열마다 NaN 값 있는 지 여부 확인
# DataFrame.all 정의
    # DataFrame.all(axis=0, bool_only=None, skipna=True, level=None, **kwargs)
    # Return whether all elements are True, potentially over an axis.
    # Returns True unless there at least one element within a series or along a Dataframe axis that is False or equivalent (e.g. zero or empty)
murd_fl_crs_eval.isnull().all(axis=0)
# Out:
# 연번                           False
# 1-1. 연수과정 만족도_맞춤형 구성         False
# 1-2. 강사 전문성                  False
# 1-3. 강의교재                    False
# 1-4.강사 영어구사력 (또는 통역 숙련도)     False
# 1-5. 참여도 제고                  False
# 1-6. 강의시간 적절성                False
# Unnamed: 8                    True
# 2-1. 연수과정 만족도_맞춤형 구성         False
# 2-2. 강사 전문성                  False
# 2-3. 강의교재                    False
# 2-4.강사 영어구사력 (또는 통역 숙련도)     False
# 2-5. 참여도 제고                  False
# 2-6. 강의시간 적절성                False
# Unnamed: 15                   True
# 3-1. 연수과정 만족도_맞춤형 구성         False
# 3-2. 강사 전문성                  False
# 3-3. 강의교재                    False
# 3-4. 강사 영어구사력 (또는 통역 숙련도)    False
# 3-5. 참여도 제고                  False
# 3-6. 강의시간 적절성                False
# Unnamed: 22                   True
# 4-1. 연수과정 만족도_맞춤형 구성         False
# 4-2. 강사 전문성                  False
# 4-3. 강의교재                    False
# 4-4. 강사 영어구사력 (또는 통역 숙련도)    False
# 4-5. 참여도 제고                  False
# 4-6. 강의시간 적절성                False
# Unnamed: 29                   True
# 5-1. 연수과정 만족도_맞춤형 구성         False
# 5-2. 강사 전문성                  False
# 5-3. 강의교재                    False
# 5-4.강사 영어구사력 (또는 통역 숙련도)     False
# 5-5. 참여도 제고                  False
# 5-6. 강의시간 적절성                False
# Unnamed: 36                   True
# 6-1. 연수과정 만족도_맞춤형 구성         False
# 6-2. 강사 전문성                  False
# 6-3. 강의교재                    False
# 6-4.강사 영어구사력 (또는 통역 숙련도)     False
# 6-5. 참여도 제고                  False
# 6-6. 강의시간 적절성                False
# Unnamed: 43                   True
# 7-1. 연수과정 만족도_맞춤형 구성         False
# 7-2. 강사 전문성                  False
# 7-3. 강의교재                    False
# 7-4.강사 영어구사력 (또는 통역 숙련도)     False
# 7-5. 참여도 제고                  False
# 7-6. 강의시간 적절성                False
# Unnamed: 50                   True
# Unnamed: 51                   True
# dtype: bool

# %%
# murd_fl_crs_eval에서 모든 열 값이 NaN 값인 경우 삭제. 삭제 후 murd_fl_crs_eval 로 반환
murd_fl_crs_eval.dropna(how='all', axis=1, inplace=True)

# %%
murd_fl_crs_eval.head()
# Out:
#                                              연번 1-1. 연수과정 만족도_맞춤형 구성  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA               1.0                    4
# Dana PHAL                                   2.0                    3
# Laura LOZADA ACOSTA                         3.0                    4
# Carmen ZANA CARBAJAL                        4.0                    5
# Peeter Hewage Chinthaka Sampath RATHNASIRI  5.0                    5
#
#                                             1-2. 강사 전문성  1-3. 강의교재  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                       4.0        4.0
# Dana PHAL                                           3.0        4.0
# Laura LOZADA ACOSTA                                 4.0        4.0
# Carmen ZANA CARBAJAL                                5.0        5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI          5.0        5.0
#
#                                             1-4.강사 영어구사력 (또는 통역 숙련도)  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                                    4.0
# Dana PHAL                                                        4.0
# Laura LOZADA ACOSTA                                              3.0
# Carmen ZANA CARBAJAL                                             5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI                       5.0
#
#                                             1-5. 참여도 제고  1-6. 강의시간 적절성  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                       4.0            4.0
# Dana PHAL                                           4.0            4.0
# Laura LOZADA ACOSTA                                 4.0            4.0
# Carmen ZANA CARBAJAL                                5.0            5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI          5.0            5.0
#
#                                             2-1. 연수과정 만족도_맞춤형 구성  2-2. 강사 전문성  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                                4.0          4.0
# Dana PHAL                                                    4.0          4.0
# Laura LOZADA ACOSTA                                          4.0          4.0
# Carmen ZANA CARBAJAL                                         5.0          5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI                   5.0          5.0
#
#                                             2-3. 강의교재      ...        \
# 성명                                                         ...
# Jean Bosco Alpha MBARUSHIMANA                     4.0      ...
# Dana PHAL                                         4.0      ...
# Laura LOZADA ACOSTA                               4.0      ...
# Carmen ZANA CARBAJAL                              5.0      ...
# Peeter Hewage Chinthaka Sampath RATHNASIRI        5.0      ...
#
#                                             6-3. 강의교재  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                     5.0
# Dana PHAL                                         5.0
# Laura LOZADA ACOSTA                               5.0
# Carmen ZANA CARBAJAL                              5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI        5.0
#
#                                             6-4.강사 영어구사력 (또는 통역 숙련도)  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                                    5.0
# Dana PHAL                                                        5.0
# Laura LOZADA ACOSTA                                              5.0
# Carmen ZANA CARBAJAL                                             5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI                       5.0
#
#                                             6-5. 참여도 제고  6-6. 강의시간 적절성  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                       5.0            5.0
# Dana PHAL                                           5.0            5.0
# Laura LOZADA ACOSTA                                 4.0            4.0
# Carmen ZANA CARBAJAL                                5.0            5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI          5.0            5.0
#
#                                             7-1. 연수과정 만족도_맞춤형 구성  7-2. 강사 전문성  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                                5.0          5.0
# Dana PHAL                                                    3.0          3.0
# Laura LOZADA ACOSTA                                          5.0          5.0
# Carmen ZANA CARBAJAL                                         5.0          5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI                   5.0          5.0
#
#                                             7-3. 강의교재  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                     5.0
# Dana PHAL                                         3.0
# Laura LOZADA ACOSTA                               4.0
# Carmen ZANA CARBAJAL                              5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI        5.0
#
#                                             7-4.강사 영어구사력 (또는 통역 숙련도)  \
# 성명
# Jean Bosco Alpha MBARUSHIMANA                                    5.0
# Dana PHAL                                                        3.0
# Laura LOZADA ACOSTA                                              5.0
# Carmen ZANA CARBAJAL                                             5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI                       5.0
#
#                                             7-5. 참여도 제고  7-6. 강의시간 적절성
# 성명
# Jean Bosco Alpha MBARUSHIMANA                       5.0            5.0
# Dana PHAL                                           3.0            2.0
# Laura LOZADA ACOSTA                                 4.0            4.0
# Carmen ZANA CARBAJAL                                5.0            5.0
# Peeter Hewage Chinthaka Sampath RATHNASIRI          5.0            5.0
#
# [5 rows x 43 columns]

# %%
murd_fl.loc[murd_fl.index.isnull(),:]
# Out:
#      성과지표  국가명      기관                    직책    근무연수   생년   성별  \
# 성명
# NaN   NaN  NaN     NaN                   NaN     NaN  NaN  NaN
# NaN   NaN  NaN      기관                    직위  기관근속년수   생년   성별
# NaN   NaN    1  중앙정부기관  장관 / 차관 / 기관장 / 국회의원     NaN  NaN  NaN
# NaN   NaN    2  지방정부기관            고위관리직/ 국장급     NaN  NaN  NaN
# NaN   NaN    3    공공기관                 중간관리직     NaN  NaN  NaN
# NaN   NaN    4      기타                  일반직원     NaN  NaN  NaN
#
#                           연수생 선발/추천을 위한 사전준비 기간은 적절하였다  \
# 성명
# NaN                                                NaN
# NaN  Preparatory period for applying and selecting ...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                       연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.  \
# 성명
# NaN                                                NaN
# NaN  I received a detailed guide on how to apply fo...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                                     교육전: A교과에 대한 인지 수준     ...      \
# 성명                                                         ...
# NaN                                                NaN     ...
# NaN  Pre-Trn: Cognitive knowledge level of learning...     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
# NaN                                                NaN     ...
#
#                                     교육후: C교과에 대한 기술 수준  \
# 성명
# NaN                                                NaN
# NaN  Post-Trn: Technical skill level of learning co...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                                  교육후: C교과에 대한 태도 수준  \
# 성명
# NaN                                             NaN
# NaN  Post-Trn: Attitude level of learning content C
# NaN                                             NaN
# NaN                                             NaN
# NaN                                             NaN
# NaN                                             NaN
#
#                      국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.  \
# 성명
# NaN                                                NaN
# NaN  The topic of the Country Report/ Action Plan w...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                                 국별보고/액션플랜 세션시간은 충분하였다.  \
# 성명
# NaN                                                NaN
# NaN  The time of the Country Report/ Action Plan se...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                      액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.  \
# 성명
# NaN                                                NaN
# NaN  There was enough advance notice for Action Pla...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                      국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.  \
# 성명
# NaN                                                NaN
# NaN  The person in charge of the Country Report/ Ac...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                     국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.  \
# 성명
# NaN                                                NaN
# NaN  The Country Report/ Action Plan  session helpe...
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
# NaN                                                NaN
#
#                    액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다. Unnamed: 47 Unnamed: 48
# 성명
# NaN                                                NaN         NaN         NaN
# NaN  Preparing an Action Plan helped to improve pra...         NaN         NaN
# NaN                                                NaN         NaN         NaN
# NaN                                                NaN         NaN         NaN
# NaN                                                NaN         NaN         NaN
# NaN                                                NaN         NaN         NaN
#
# [6 rows x 48 columns]

# %%
murd_fl.index.notnull()
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True, False, False, False, False, False,
#        False])

# %%
# 인덱스 행이 NaN 값인 경우, 해당 행 삭제
murd_fl.drop(murd_fl.index.isnull() == True, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-c249751d6426> in <module>
#       1 # 인덱스 행이 NaN 값인 경우, 해당 행 삭제
# ----> 2 murd_fl.drop(murd_fl.index.isnull() == True, axis=0)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3160                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3161                 if errors == 'raise' and labels_missing:
# -> 3162                     raise KeyError('{} not found in axis'.format(labels))
#    3163
#    3164             slicer = [slice(None)] * self.ndim
#
# KeyError: '[False False False False False False False False False False False False\n False True True True True True True] not found in axis'

# %%
# murd_fl index에서 행 값이 NaN인 행 제거
murd_fl.drop(, axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-79-b1ff7d19aa5f> in <module>
#       1 # murd_fl index에서 행 값이 NaN인 행 제거
# ----> 2 murd_fl.drop(murd_fl.loc[murd_fl.index.isnull(),:], axis=0)
#
# C:\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3695                                            index=index, columns=columns,
#    3696                                            level=level, inplace=inplace,
# -> 3697                                            errors=errors)
#    3698
#    3699     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3109         for axis, labels in axes.items():
#    3110             if labels is not None:
# -> 3111                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3112
#    3113         if inplace:
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3160                 labels_missing = (axis.get_indexer_for(labels) == -1).any()
#    3161                 if errors == 'raise' and labels_missing:
# -> 3162                     raise KeyError('{} not found in axis'.format(labels))
#    3163
#    3164             slicer = [slice(None)] * self.ndim
#
# KeyError: "['성과지표' '국가명' '기관' '직책' '근무연수' '생년' '성별' '연수생 선발/추천을 위한 사전준비 기간은 적절하였다'\n '연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.' '교육전: A교과에 대한 인지 수준'\n '교육전: A교과에 대한 기술 수준' '교육전: A교과에 대한 태도 수준' '교육전: B교과에 대한 인지 수준'\n '교육전: B교과에 대한 기술 수준' '교육전: B교과에 대한 태도 수준' '교육전: C교과에 대한 인지 수준'\n '교육전: C교과에 대한 기술 수준' '교육전: C교과에 대한 태도 수준'\n '연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.' '연수과정의 내용과 수준은 이해하기 적절하였다.'\n '연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.'\n '연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다'\n '연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)'\n '연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.' '강의실 및 실습실은 사용하기에 편리하였다.'\n '연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다. ' '귀하께서 참여하신 연수과정에 통역사가 있었습니까?'\n '연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)'\n '강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.'\n '강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다'\n '통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)'\n '교육후: A교과에 대한 인지 수준' '교육후: A교과에 대한 기술 수준' '교육후: A교과에 대한 태도 수준'\n '교육후: B교과에 대한 인지 수준' '교육후: B교과에 대한 기술 수준' '교육후: B교과에 대한 태도 수준'\n '교육후: C교과에 대한 인지 수준' '교육후: C교과에 대한 기술 수준' '교육후: C교과에 대한 태도 수준'\n '국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.' '국별보고/액션플랜 세션시간은 충분하였다.'\n '액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.' '국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.'\n '국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.'\n '액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.' 'Unnamed: 47' 'Unnamed: 48'] not found in axis"

# %%
# murd_fl = murd_fl.drop(['성과지표', 'Unnamed: 47', 'Unnamed: 48'], axis=1)
# murd_fl = 
murd_fl.dropna(
    
    murd_fl.loc[murd_fl.index,:]
    murd_fl.index, how='all', axis=0)
# murd_fl
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-a2118f2ea381> in <module>
#       1 # murd_fl = murd_fl.drop(['성과지표', 'Unnamed: 47', 'Unnamed: 48'], axis=1)
#       2 # murd_fl =
# ----> 3 murd_fl.dropna(murd_fl.index, how='all', axis=0)
#       4 # murd_fl
#
# TypeError: dropna() got multiple values for argument 'axis'

# %% [markdown]
# * 분리된 dataframe을 병합방법: concat, join, merge
#   * concat은 dataframe의 크기가 동일할 경우 dataframe 병합가능 (python append의 다차원 배열 버전)
#   * join은 dataframe의 크기가 동일하지 않을 경우 key를 기점으로 동일한 부분은 맞춰서 합쳐주고 나머지는 NaN으로 처리한다.
#
# * concat의 경우 하나의 서로 다른 dataframe 에서 column을 뽑아서 하나로 합칠 때 유용하다.
#   * pd.concat([df['a열'],df['b열']], axis=1): a열과 b열 병합, axis=0 이면 column나뉘지 않고 아래에 쌓여 1개의 column 형성
#   * 아래는 1-2열/5-끝열 추출 후 병합
#
# murd_fl = pd.concat([murd_fl.iloc[:,1:3],murd_fl.loc[:,'근무연수':]],axis=1).sort_values(by='성명').reset_index(drop=True)

# %%
murd_fl.index
# Out:
# Index([                                 'Dana PHAL',
#                         'Alejandro CEBALLOS JARABA',
#                  'Jacqueline Yamileth RIVERA AYALA',
#                                   'Edward AGBODJAN',
#                              'Mercy Wairimu KIMANI',
#                           'Khin Ohnmar MYINT THEIN',
#                                       'Hnin Ei Mon',
#                                       'Iqbal AHMED',
#                               'Laura LOZADA ACOSTA',
#                              'Carmen ZANA CARBAJAL',
#                     'Joz Carlos Gabrillo ORDILLANO',
#                     'Jean Bosco Alpha MBARUSHIMANA',
#        'Peeter Hewage Chinthaka Sampath RATHNASIRI',
#                                                 nan,
#                                                 nan,
#                                                 nan,
#                                                 nan,
#                                                 nan,
#                                                 nan],
#       dtype='object', name='성명')

# %%
# sort_values를 호출 후 해당 변수를 정렬하면 뒤죽박죽 된 인덱스를 .reset_index()로 초기화 (출처: https://3months.tistory.com/196)
murd_info = murd_info[
            murd_info['성명'].isin(['Dana PHAL', 'Alejandro CEBALLOS JARABA','Jacqueline Yamileth RIVERA AYALA',
                                    'Edward AGBODJAN','Mercy Wairimu KIMANI', 'Khin Ohnmar MYINT THEIN', 'Hnin Ei Mon',
                                    'Iqbal AHMED', 'Laura LOZADA ACOSTA', 'Carmen ZANA CARBAJAL','Joz Carlos Gabrillo ORDILLANO',
                                    'Jean Bosco Alpha MBARUSHIMANA','Peeter Hewage Chinthaka Sampath RATHNASIRI'])].sort_values(
                                     by='성명')
murd_info.head(2)
# Out:
#            학번    전공  수   참가기간(시작)   참가기간(종료)   체류기간(시작)   체류기간(종료)  \
# 17  IU2014418  MURD  1 2014-08-01 2016-02-29 2014-08-01 2015-12-31
# 53  IU2016414  MURD  3 2016-08-01 2018-02-28 2016-08-01 2017-12-31
#
#                            성명           성명_국문       대륙    ...    국외여행일수4  \
# 17  Alejandro CEBALLOS JARABA  체발로스 자라바 알레한드로  AMERICA    ...        NaN
# 53       Carmen ZANA CARBAJAL     자나 카르바잘 카르멘  AMERICA    ...        NaN
#
#    국외여행합계 논문분야 논문평점                             소속분류 소속분류2 소속분류3     소속분류_Kor  \
# 17    NaN  NaN  NaN  Housing & Community Development   NaN   NaN  주택과 지역사회 개발
# 53    NaN  NaN  NaN        Project Feasibility Study   NaN   NaN      사업타당성조사
#
#    소속분류2_Kor 소속분류3_Kor
# 17       NaN       NaN
# 53       NaN       NaN
#
# [2 rows x 86 columns]

# %%
murd_fl = pd.merge(murd_fl, murd_info, left_on='성명', right_on='성명') 
# 같은 결과: murd_fl = pd.concat([murd_fl, murd_info], axis=1)
# 같은 결과: murd_fl = pd.merge(murd_fl, murd_info, left_index=True, right_index=True)
murd_fl
# Out:
#                                             성명    국가명      기관          직책  \
# 0                                    Dana PHAL   캄보디아  중앙정부기관        일반직원
# 1                    Alejandro CEBALLOS JARABA   콜롬비아  중앙정부기관        일반직원
# 2             Jacqueline Yamileth RIVERA AYALA  엘살바도르  중앙정부기관        일반직원
# 3                              Edward AGBODJAN     가나  중앙정부기관       중간관리직
# 4                         Mercy Wairimu KIMANI     케냐  중앙정부기관  고위관리직/ 국장급
# 5                      Khin Ohnmar MYINT THEIN    미얀마  중앙정부기관       중간관리직
# 6                                  Hnin Ei Mon    미얀마  중앙정부기관       중간관리직
# 7                                  Iqbal AHMED   파키스탄  중앙정부기관       중간관리직
# 8                          Laura LOZADA ACOSTA     페루      기타        일반직원
# 9                         Carmen ZANA CARBAJAL     페루    공공기관       중간관리직
# 10               Joz Carlos Gabrillo ORDILLANO    필리핀  중앙정부기관       중간관리직
# 11               Jean Bosco Alpha MBARUSHIMANA    르완다  중앙정부기관        일반직원
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI   스리랑카  중앙정부기관  고위관리직/ 국장급
#
#    근무연수    생년 성별_x 연수생 선발/추천을 위한 사전준비 기간은 적절하였다  \
# 0     6  1987    여                            5
# 1     5  1987    남                            5
# 2     3  1987    여                            4
# 3     8  1981    남                            5
# 4    13  1976    여                            4
# 5    15  1978    여                            5
# 6     9  1985    여                            5
# 7    17  1976    남                            5
# 8     3  1988    여                            4
# 9     5  1985    여                            5
# 10    8  1989    남                            4
# 11    8  1981    남                            5
# 12    8  1984    남                            5
#
#    연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다. 교육전: A교과에 대한 인지 수준     ...      국외여행일수4  \
# 0                                 4                  3     ...          NaN
# 1                                 5                  3     ...          NaN
# 2                                 4                  4     ...          NaN
# 3                                 4                  5     ...          NaN
# 4                                 5                  2     ...          NaN
# 5                                 5                  3     ...          NaN
# 6                                 4                  2     ...          NaN
# 7                                 5                  5     ...          NaN
# 8                                 4                  4     ...          NaN
# 9                                 5                  5     ...          NaN
# 10                                5                  5     ...          NaN
# 11                                5                  2     ...          NaN
# 12                                5                  2     ...          NaN
#
#    국외여행합계 논문분야 논문평점                                      소속분류  \
# 0     NaN  NaN  NaN           Construction/Project Management
# 1     NaN  NaN  NaN           Housing & Community Development
# 2     NaN  NaN  NaN                       Disaster Management
# 3     NaN  NaN  NaN                        Transport Planning
# 4     NaN  NaN  NaN           Housing & Community Development
# 5     NaN  NaN  NaN                  Infrastructure Financing
# 6     NaN  NaN  NaN         Public-Private-Partnerships (PPP)
# 7     NaN  NaN  NaN                        Urban Regeneration
# 8     NaN  NaN  NaN           Regional Development / Policies
# 9     NaN  NaN  NaN                 Project Feasibility Study
# 10    NaN  NaN  NaN  Transportation & Land Use (Compact City)
# 11    NaN  NaN  NaN                      Green Infrastructure
# 12    NaN  NaN  NaN             Balanced Regional Development
#
#                               소속분류2 소속분류3     소속분류_Kor    소속분류2_Kor  \
# 0                               NaN   NaN   건설 프로젝트 관리          NaN
# 1                               NaN   NaN  주택과 지역사회 개발          NaN
# 2                               NaN   NaN        재해 관리          NaN
# 3                               NaN   NaN        교통 계획          NaN
# 4                               NaN   NaN  주택과 지역사회 개발          NaN
# 5                               NaN   NaN     인프라 파이낸싱          NaN
# 6                               NaN   NaN         민관협력          NaN
# 7   Housing Policy / Public Housing   NaN         도시재생  주택정책 / 공공주택
# 8                               NaN   NaN     지역 개발 정책          NaN
# 9                               NaN   NaN      사업타당성조사          NaN
# 10                              NaN   NaN    교통과 토지 이용          NaN
# 11                              NaN   NaN       녹색 인프라          NaN
# 12                              NaN   NaN       지역균형발전          NaN
#
#       소속분류3_Kor
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7   주택정책 / 공공주택
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
#
# [13 rows x 131 columns]

# %%
murd_fl.columns.values
# Out:
# array(['성명', '국가명', '기관', '직책', '근무연수', '생년', '성별_x',
#        '연수생 선발/추천을 위한 사전준비 기간은 적절하였다', '연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.',
#        '교육전: A교과에 대한 인지 수준', '교육전: A교과에 대한 기술 수준', '교육전: A교과에 대한 태도 수준',
#        '교육전: B교과에 대한 인지 수준', '교육전: B교과에 대한 기술 수준', '교육전: B교과에 대한 태도 수준',
#        '교육전: C교과에 대한 인지 수준', '교육전: C교과에 대한 기술 수준', '교육전: C교과에 대한 태도 수준',
#        '연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.', '연수과정의 내용과 수준은 이해하기 적절하였다.',
#        '연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.',
#        '연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다',
#        '연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)',
#        '연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.', '강의실 및 실습실은 사용하기에 편리하였다.',
#        '연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다. ',
#        '귀하께서 참여하신 연수과정에 통역사가 있었습니까?',
#        '연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)',
#        '강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.',
#        '강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다',
#        '통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)',
#        '교육후: A교과에 대한 인지 수준', '교육후: A교과에 대한 기술 수준', '교육후: A교과에 대한 태도 수준',
#        '교육후: B교과에 대한 인지 수준', '교육후: B교과에 대한 기술 수준', '교육후: B교과에 대한 태도 수준',
#        '교육후: C교과에 대한 인지 수준', '교육후: C교과에 대한 기술 수준', '교육후: C교과에 대한 태도 수준',
#        '국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.', '국별보고/액션플랜 세션시간은 충분하였다.',
#        '액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.',
#        '국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.',
#        '국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.',
#        '액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.', '학번', '전공', '수', '참가기간(시작)',
#        '참가기간(종료)', '체류기간(시작)', '체류기간(종료)', '성명_국문', '대륙', '대륙_국문', '대륙2',
#        '대륙2_국문', '국가', '국가_국문', '도시', '도시_국문', '기관분류', '생년월일', '주민번호',
#        '성별_y', '소속', '직위', '자국내 주소', '이메일', '연락처(자국)', '핸드폰', '기숙사번호',
#        '포털아이디', '비번', '학적', '학적2', '졸업일', '은행', '계좌', '계좌주', '외국인등록증 만료일',
#        '기피음식', '대표', '세부전공', '총평균평점', '논문제목', '지도교수', '인턴십', '인턴십_국문',
#        '배치부서', '인턴십 기간(시작)', '인턴십 기간(종료)', '인턴십 비고', '인턴십2', '인턴십_국문2',
#        '배치부서2', '인턴십 기간2(시작)', '인턴십 기간2(종료)', '인턴십 비고2', '인턴십3',
#        '인턴십_국문3', '배치부서3', '인턴십 기간3(시작)', '인턴십 기간3(종료)', '인턴십 비고3',
#        '국외여행1-1', '국외여행1-2', '행선지1', '국외여행일수1', '국외여행2-1', '국외여행2-2',
#        '행선지2', '국외여행일수2', '국외여행3-1', '국외여행3-2', '행선지3', '국외여행일수3',
#        '국외여행4-1', '국외여행4-2', '행선지4', '국외여행일수4', '국외여행합계', '논문분야', '논문평점',
#        '소속분류', '소속분류2', '소속분류3', '소속분류_Kor', '소속분류2_Kor', '소속분류3_Kor'],
#       dtype=object)

# %% [markdown]
# ## 설문분석

# %% [markdown]
# ### 교육전 설문

# %% [markdown]
# #### 연수생 선발/추천을 위한 사전준비 기간은 적절하였다

# %%
display(murd_fl.iloc[:,[0,7]])
# countplot 명령을 사용하면 각 카테고리 값별로 데이터가 얼마나 있는지 표시할 수 있다.
# countplot 명령은 데이터프레임에만 사용할 수 있다. 사용 방법은 다음과 같다.
plt.show(sns.countplot(x='연수생 선발/추천을 위한 사전준비 기간은 적절하였다', data =murd_fl.iloc[:,[0,7]]))
# Out:
#                                             성명 연수생 선발/추천을 위한 사전준비 기간은 적절하였다
# 0                                    Dana PHAL                            5
# 1                    Alejandro CEBALLOS JARABA                            5
# 2             Jacqueline Yamileth RIVERA AYALA                            4
# 3                              Edward AGBODJAN                            5
# 4                         Mercy Wairimu KIMANI                            4
# 5                      Khin Ohnmar MYINT THEIN                            5
# 6                                  Hnin Ei Mon                            5
# 7                                  Iqbal AHMED                            5
# 8                          Laura LOZADA ACOSTA                            4
# 9                         Carmen ZANA CARBAJAL                            5
# 10               Joz Carlos Gabrillo ORDILLANO                            4
# 11               Jean Bosco Alpha MBARUSHIMANA                            5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                            5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,7]]['연수생 선발/추천을 위한 사전준비 기간은 적절하였다'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수생 선발/추천을 위한 사전준비 기간은 적절하였다
# 응답자수                             13
# 답변유형                              2
# 최빈값                               5
# 최빈값빈도                             9

# %% [markdown]
# #### 연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다

# %%
display(murd_fl.iloc[:,[0,8]])
plt.show(sns.countplot(x='연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.', data =murd_fl.iloc[:,[0,8]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.
# 0                                 4
# 1                                 5
# 2                                 4
# 3                                 4
# 4                                 5
# 5                                 5
# 6                                 4
# 7                                 5
# 8                                 4
# 9                                 5
# 10                                5
# 11                                5
# 12                                5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,8]]['연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.
# 응답자수                                 13
# 답변유형                                  2
# 최빈값                                   5
# 최빈값빈도                                 8

# %% [markdown]
# ### 교육후 설문

# %% [markdown]
# ####  연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.

# %%
display(murd_fl.iloc[:,[0,18]])
plt.show(sns.countplot(x='연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.', data =murd_fl.iloc[:,[0,18]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.
# 0                                    3
# 1                                    4
# 2                                    4
# 3                                    4
# 4                                    5
# 5                                    4
# 6                                    5
# 7                                    5
# 8                                    4
# 9                                    5
# 10                                   5
# 11                                   5
# 12                                   5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,18]]['연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.
# 응답자수                                    13
# 답변유형                                     3
# 최빈값                                      5
# 최빈값빈도                                    7

# %% [markdown]
# #### 연수과정의 내용과 수준은 이해하기 적절하였다.

# %%
display(murd_fl.iloc[:,[0,19]])
plt.show(sns.countplot(x='연수과정의 내용과 수준은 이해하기 적절하였다.', data =murd_fl.iloc[:,[0,19]]))
# Out:
#                                             성명 연수과정의 내용과 수준은 이해하기 적절하였다.
# 0                                    Dana PHAL                         3
# 1                    Alejandro CEBALLOS JARABA                         5
# 2             Jacqueline Yamileth RIVERA AYALA                         5
# 3                              Edward AGBODJAN                         5
# 4                         Mercy Wairimu KIMANI                         5
# 5                      Khin Ohnmar MYINT THEIN                         4
# 6                                  Hnin Ei Mon                         4
# 7                                  Iqbal AHMED                         5
# 8                          Laura LOZADA ACOSTA                         4
# 9                         Carmen ZANA CARBAJAL                         5
# 10               Joz Carlos Gabrillo ORDILLANO                         5
# 11               Jean Bosco Alpha MBARUSHIMANA                         5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                         5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,19]]['연수과정의 내용과 수준은 이해하기 적절하였다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수과정의 내용과 수준은 이해하기 적절하였다.
# 응답자수                          13
# 답변유형                           3
# 최빈값                            5
# 최빈값빈도                          9

# %% [markdown]
# #### 연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.

# %%
display(murd_fl.iloc[:,[0,20]])
plt.show(sns.countplot(x='연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.', data =murd_fl.iloc[:,[0,20]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.
# 0                                                  3
# 1                                                  5
# 2                                                  4
# 3                                                  5
# 4                                                  5
# 5                                                  4
# 6                                                  5
# 7                                                  5
# 8                                                  4
# 9                                                  5
# 10                                                 4
# 11                                                 5
# 12                                                 5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,20]]['연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.
# 응답자수                                                  13
# 답변유형                                                   3
# 최빈값                                                    5
# 최빈값빈도                                                  8

# %% [markdown]
# #### 연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다

# %%
display(murd_fl.iloc[:,[0,21]])
plt.show(sns.countplot(x='연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다', data =murd_fl.iloc[:,[0,21]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다
# 0                                      4
# 1                                      3
# 2                                      3
# 3                                      5
# 4                                      5
# 5                                      4
# 6                                      5
# 7                                      5
# 8                                      4
# 9                                      5
# 10                                     5
# 11                                     5
# 12                                     5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,21]]['연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다
# 응답자수                                      13
# 답변유형                                       3
# 최빈값                                        5
# 최빈값빈도                                      8

# %% [markdown]
# #### 연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)

# %%
display(murd_fl.iloc[:,[0,22]])
plt.show(sns.countplot(x='연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)', 
                       data =murd_fl.iloc[:,[0,22]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)
# 0                                                4
# 1                                                4
# 2                                                3
# 3                                                5
# 4                                                5
# 5                                                4
# 6                                                4
# 7                                                5
# 8                                                4
# 9                                                5
# 10                                               5
# 11                                               5
# 12                                               5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,22]][
    '연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)
# 응답자수                                                13
# 답변유형                                                 3
# 최빈값                                                  5
# 최빈값빈도                                                7

# %% [markdown]
# #### 연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.

# %%
display(murd_fl.iloc[:,[0,23]])
plt.show(sns.countplot(x='연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.', data =murd_fl.iloc[:,[0,23]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.
# 0                                  4
# 1                                  5
# 2                                  5
# 3                                  5
# 4                                  5
# 5                                  4
# 6                                  4
# 7                                  5
# 8                                  3
# 9                                  5
# 10                                 4
# 11                                 5
# 12                                 5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,23]]['연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.
# 응답자수                                  13
# 답변유형                                   3
# 최빈값                                    5
# 최빈값빈도                                  8

# %% [markdown]
# #### 강의실 및 실습실은 사용하기에 편리하였다.

# %%
display(murd_fl.iloc[:,[0,24]])
plt.show(sns.countplot(x='강의실 및 실습실은 사용하기에 편리하였다.', data =murd_fl.iloc[:,[0,24]]))
# Out:
#                                             성명 강의실 및 실습실은 사용하기에 편리하였다.
# 0                                    Dana PHAL                       4
# 1                    Alejandro CEBALLOS JARABA                       5
# 2             Jacqueline Yamileth RIVERA AYALA                       5
# 3                              Edward AGBODJAN                       5
# 4                         Mercy Wairimu KIMANI                       4
# 5                      Khin Ohnmar MYINT THEIN                       5
# 6                                  Hnin Ei Mon                       4
# 7                                  Iqbal AHMED                       5
# 8                          Laura LOZADA ACOSTA                       4
# 9                         Carmen ZANA CARBAJAL                       5
# 10               Joz Carlos Gabrillo ORDILLANO                       5
# 11               Jean Bosco Alpha MBARUSHIMANA                       5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                       5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,24]]['강의실 및 실습실은 사용하기에 편리하였다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        강의실 및 실습실은 사용하기에 편리하였다.
# 응답자수                        13
# 답변유형                         2
# 최빈값                          5
# 최빈값빈도                        9

# %% [markdown]
# #### 연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다.

# %%
display(murd_fl.iloc[:,[0,25]])
plt.show(sns.countplot(x='연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다. ', data =murd_fl.iloc[:,[0,25]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다.
# 0                                         3
# 1                                         3
# 2                                         5
# 3                                         5
# 4                                         4
# 5                                         4
# 6                                         4
# 7                                         4
# 8                                         4
# 9                                         5
# 10                                        4
# 11                                        5
# 12                                        5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,25]]['연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다. '].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다.
# 응답자수                                         13
# 답변유형                                          3
# 최빈값                                           4
# 최빈값빈도                                         6

# %% [markdown]
# #### 연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)

# %%
display(murd_fl.iloc[:,[0,27]])
plt.show(sns.countplot(x='연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)', 
                       data =murd_fl.iloc[:,[0,27]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)
# 0                                           3
# 1                                           5
# 2                                           5
# 3                                           5
# 4                                           5
# 5                                           4
# 6                                           5
# 7                                           5
# 8                                           4
# 9                                           5
# 10                                          5
# 11                                          5
# 12                                          5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,27]]['연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)
# 응답자수                                           13
# 답변유형                                            3
# 최빈값                                             5
# 최빈값빈도                                          10

# %% [markdown]
# #### 강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.

# %%
display(murd_fl.iloc[:,[0,28]])
plt.show(sns.countplot(x='강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.',
                       data =murd_fl.iloc[:,[0,28]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.
# 0                                             4
# 1                                             5
# 2                                             5
# 3                                             5
# 4                                             5
# 5                                             4
# 6                                             5
# 7                                             5
# 8                                             4
# 9                                             5
# 10                                            5
# 11                                            5
# 12                                            5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,28]]['강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.
# 응답자수                                             13
# 답변유형                                              2
# 최빈값                                               5
# 최빈값빈도                                            10

# %% [markdown]
# #### 강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다

# %%
display(murd_fl.iloc[:,[0,29]])
plt.show(sns.countplot(x='강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다', data =murd_fl.iloc[:,[0,29]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다
# 0                                     3
# 1                                     5
# 2                                     4
# 3                                     5
# 4                                     5
# 5                                     4
# 6                                     5
# 7                                     5
# 8                                     5
# 9                                     5
# 10                                    5
# 11                                    5
# 12                                    5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,29]]['강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다
# 응답자수                                     13
# 답변유형                                      3
# 최빈값                                       5
# 최빈값빈도                                    10

# %% [markdown]
# #### 통역사는 이해하기 쉽도록 통역하였다.

# %%
display(murd_fl.iloc[:,[0,30]])
plt.show(sns.countplot(x='통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)', 
                       data =murd_fl.iloc[:,[0,30]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)
# 0                                                   4
# 1                                                   5
# 2                                                   5
# 3                                                   5
# 4                                                   5
# 5                                                   4
# 6                                                   4
# 7                                                   5
# 8                                                 NaN
# 9                                                 NaN
# 10                                                  4
# 11                                                  5
# 12                                                  5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,30]]['통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)
# 응답자수                                                  11
# 답변유형                                                   2
# 최빈값                                                    5
# 최빈값빈도                                                  7

# %% [markdown]
# #### 국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.

# %%
display(murd_fl.iloc[:,[0,40]])
plt.show(sns.countplot(x='국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.', data =murd_fl.iloc[:,[0,40]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.
# 0                                  4
# 1                                  4
# 2                                  3
# 3                                  5
# 4                                  5
# 5                                  4
# 6                                  4
# 7                                  5
# 8                                  4
# 9                                  5
# 10                                 5
# 11                                 4
# 12                                 5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,40]]['국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.
# 응답자수                                  13
# 답변유형                                   3
# 최빈값                                    5
# 최빈값빈도                                  6

# %% [markdown]
# #### 국별보고/액션플랜 세션시간은 충분하였다.

# %%
display(murd_fl.iloc[:,[0,41]])
plt.show(sns.countplot(x='국별보고/액션플랜 세션시간은 충분하였다.', data =murd_fl.iloc[:,[0,41]]))
# Out:
#                                             성명 국별보고/액션플랜 세션시간은 충분하였다.
# 0                                    Dana PHAL                      3
# 1                    Alejandro CEBALLOS JARABA                      3
# 2             Jacqueline Yamileth RIVERA AYALA                      2
# 3                              Edward AGBODJAN                      3
# 4                         Mercy Wairimu KIMANI                      5
# 5                      Khin Ohnmar MYINT THEIN                      2
# 6                                  Hnin Ei Mon                      4
# 7                                  Iqbal AHMED                      5
# 8                          Laura LOZADA ACOSTA                      2
# 9                         Carmen ZANA CARBAJAL                      5
# 10               Joz Carlos Gabrillo ORDILLANO                      5
# 11               Jean Bosco Alpha MBARUSHIMANA                      3
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                      5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,41]]['국별보고/액션플랜 세션시간은 충분하였다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        국별보고/액션플랜 세션시간은 충분하였다.
# 응답자수                       13
# 답변유형                        4
# 최빈값                         5
# 최빈값빈도                       5

# %% [markdown]
# #### 액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.

# %%
display(murd_fl.iloc[:,[0,42]])
plt.show(sns.countplot(x='액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.', data =murd_fl.iloc[:,[0,42]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.
# 0                                  3
# 1                                  3
# 2                                  3
# 3                                  4
# 4                                  5
# 5                                  4
# 6                                  5
# 7                                  5
# 8                                  2
# 9                                  5
# 10                                 5
# 11                                 4
# 12                                 5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,42]]['액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.
# 응답자수                                  13
# 답변유형                                   4
# 최빈값                                    5
# 최빈값빈도                                  6

# %% [markdown]
# #### 국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.

# %%
display(murd_fl.iloc[:,[0,43]])
plt.show(sns.countplot(x='국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.', 
                       data =murd_fl.iloc[:,[0,43]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.
# 0                                  3
# 1                                  5
# 2                                  4
# 3                                  5
# 4                                  5
# 5                                  4
# 6                                  5
# 7                                  5
# 8                                  4
# 9                                  5
# 10                                 5
# 11                                 4
# 12                                 5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,43]]['국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.
# 응답자수                                  13
# 답변유형                                   3
# 최빈값                                    5
# 최빈값빈도                                  8

# %% [markdown]
# #### 국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.

# %%
display(murd_fl.iloc[:,[0,44]])
plt.show(sns.countplot(x='국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.', data =murd_fl.iloc[:,[0,44]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.
# 0                                   3
# 1                                   5
# 2                                   5
# 3                                   4
# 4                                   5
# 5                                   4
# 6                                   4
# 7                                   5
# 8                                   4
# 9                                   5
# 10                                  5
# 11                                  5
# 12                                  5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,44]]['국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.
# 응답자수                                   13
# 답변유형                                    3
# 최빈값                                     5
# 최빈값빈도                                   8

# %% [markdown]
# #### 액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.

# %%
display(murd_fl.iloc[:,[0,45]])
plt.show(sns.countplot(x='액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.', data =murd_fl.iloc[:,[0,45]]))
# Out:
#                                             성명  \
# 0                                    Dana PHAL
# 1                    Alejandro CEBALLOS JARABA
# 2             Jacqueline Yamileth RIVERA AYALA
# 3                              Edward AGBODJAN
# 4                         Mercy Wairimu KIMANI
# 5                      Khin Ohnmar MYINT THEIN
# 6                                  Hnin Ei Mon
# 7                                  Iqbal AHMED
# 8                          Laura LOZADA ACOSTA
# 9                         Carmen ZANA CARBAJAL
# 10               Joz Carlos Gabrillo ORDILLANO
# 11               Jean Bosco Alpha MBARUSHIMANA
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI
#
#    액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.
# 0                                    3
# 1                                    5
# 2                                    5
# 3                                    5
# 4                                    5
# 5                                    3
# 6                                    4
# 7                                    5
# 8                                    4
# 9                                    5
# 10                                   5
# 11                                   5
# 12                                   5

# %%
pd.DataFrame(murd_fl.iloc[:,[0,45]]['액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.'].describe()).rename(
    index={'count': '응답자수','unique': '답변유형','top': '최빈값','freq': '최빈값빈도'})
# Out:
#        액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.
# 응답자수                                    13
# 답변유형                                     3
# 최빈값                                      5
# 최빈값빈도                                    9

# %% [markdown]
# ## 교육전후 교과별 '인지 수준 - 기술 수준 - 태도 수준' 변화 분석

# %%
murd_fl_pre_post = murd_fl[['성명','교육전: A교과에 대한 인지 수준','교육후: A교과에 대한 인지 수준',
       '교육전: A교과에 대한 기술 수준', '교육후: A교과에 대한 기술 수준',
       '교육전: A교과에 대한 태도 수준','교육후: A교과에 대한 태도 수준',
       '교육전: B교과에 대한 인지 수준', '교육후: B교과에 대한 인지 수준',
       '교육전: B교과에 대한 기술 수준','교육후: B교과에 대한 기술 수준',
       '교육전: B교과에 대한 태도 수준','교육후: B교과에 대한 태도 수준',
       '교육전: C교과에 대한 인지 수준', '교육후: C교과에 대한 인지 수준',
       '교육전: C교과에 대한 기술 수준','교육후: C교과에 대한 기술 수준',
       '교육전: C교과에 대한 태도 수준', '교육후: C교과에 대한 태도 수준']]

#  = murd_fl_pre_post = pd.concat([murd_fl_pre, murd_fl_post.iloc[:, 1: ]],axis=1)

murd_fl_post = murd_fl[['성명','교육후: A교과에 대한 인지 수준',
       '교육후: A교과에 대한 기술 수준', '교육후: A교과에 대한 태도 수준',
       '교육후: B교과에 대한 인지 수준','교육후: B교과에 대한 기술 수준',
       '교육후: B교과에 대한 태도 수준','교육후: C교과에 대한 인지 수준',
       '교육후: C교과에 대한 기술 수준','교육후: C교과에 대한 태도 수준']]
murd_fl_pre = murd_fl[['성명','교육전: A교과에 대한 인지 수준',
       '교육전: A교과에 대한 기술 수준', '교육전: A교과에 대한 태도 수준',
       '교육전: B교과에 대한 인지 수준','교육전: B교과에 대한 기술 수준',
       '교육전: B교과에 대한 태도 수준','교육전: C교과에 대한 인지 수준',
       '교육전: C교과에 대한 기술 수준','교육전: C교과에 대한 태도 수준']]

# %%
murd_fl_pre_post.head()
# Out:
#                                  성명 교육전: A교과에 대한 인지 수준 교육후: A교과에 대한 인지 수준  \
# 0                         Dana PHAL                  3                  2
# 1         Alejandro CEBALLOS JARABA                  3                  4
# 2  Jacqueline Yamileth RIVERA AYALA                  4                  5
# 3                   Edward AGBODJAN                  5                  5
# 4              Mercy Wairimu KIMANI                  2                  5
#
#   교육전: A교과에 대한 기술 수준 교육후: A교과에 대한 기술 수준 교육전: A교과에 대한 태도 수준 교육후: A교과에 대한 태도 수준  \
# 0                  2                  2                  3                  2
# 1                  3                  3                  5                  4
# 2                  3                  3                  5                  4
# 3                  3                  3                  4                  5
# 4                  2                  5                  5                  5
#
#   교육전: B교과에 대한 인지 수준 교육후: B교과에 대한 인지 수준 교육전: B교과에 대한 기술 수준 교육후: B교과에 대한 기술 수준  \
# 0                  2                  2                  1                  1
# 1                  3                  4                  3                  3
# 2                  5                  4                  5                  3
# 3                  1                  4                  3                  3
# 4                  2                  4                  2                  4
#
#   교육전: B교과에 대한 태도 수준 교육후: B교과에 대한 태도 수준 교육전: C교과에 대한 인지 수준 교육후: C교과에 대한 인지 수준  \
# 0                  2                  2                  2                  3
# 1                  4                  4                  2                  5
# 2                  5                  4                  4                  3
# 3                  2                  3                  4                  5
# 4                  5                  4                  2                  4
#
#   교육전: C교과에 대한 기술 수준 교육후: C교과에 대한 기술 수준 교육전: C교과에 대한 태도 수준 교육후: C교과에 대한 태도 수준
# 0                  2                  3                  3                  3
# 1                  4                  4                  5                  4
# 2                  5                  3                  4                  3
# 3                  3                  3                  3                  5
# 4                  2                  4                  5                  4

# %% [markdown]
# * A교과: Understanding Public-Private Partnership and Its Applicability to Developing Countries (PPP와 개도국에 대한 PPP적용방법에 대한 이해)
# * B교과: Applicable Water Quality Improvement Technique for Developing Countries (개도국을 위한 적용가능한 수질개선기술)
# * C교과: Developing a Media City and Road and Traffic Facility for Developing Countries (개도국을 위한 미디어시티, 도로, 교통시설 개발)

# %% [markdown]
# ### 'PPP와 개도국에 대한 PPP적용방법에 대한 이해 (A교과)'에 대한 참가자별 '인지 - 기술 - 태도' 수준 변화

# %% [markdown]
# #### A교과에 대한 인지 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index

df_cog_a = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: A교과에 대한 인지 수준'],
                           murd_fl['교육전: A교과에 대한 인지 수준']
                          ],axis=1)

df_cog_a['교육전후 A교과에 대한 인지 수준 변화'] = \
                           murd_fl['교육후: A교과에 대한 인지 수준'] - \
                           murd_fl["교육전: A교과에 대한 인지 수준"]

df_cog_a_bef_af_gap = df_cog_a.sort_values(by='교육전후 A교과에 대한 인지 수준 변화',
                            ascending=True).reset_index(drop='index')

df_cog_a_bef_af_gap

plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_cog_a_bef_af_gap))
p1 = plt.barh(index, df_cog_a_bef_af_gap["교육전: A교과에 대한 인지 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_cog_a_bef_af_gap['교육후: A교과에 대한 인지 수준'],  
              align='center', label='Post-Training', left=df_cog_a_bef_af_gap["교육전: A교과에 대한 인지 수준"])

plt.title('교육전후 A교과에 대한 인지 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('인지 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_cog_a_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()

# for i, rect in enumerate(p1):
#     plt.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0,
#          str(df_cog_a_bef_af_gap["교육전: A교과에 대한 인지 수준 변화"][i]),
#          fontsize=15, color='w', ha='right', va='center')
# Out:
#                                             성명 교육후: A교과에 대한 인지 수준  \
# 0                                    Dana PHAL                  2
# 1                              Edward AGBODJAN                  5
# 2                      Khin Ohnmar MYINT THEIN                  3
# 3                                  Iqbal AHMED                  5
# 4                          Laura LOZADA ACOSTA                  4
# 5                         Carmen ZANA CARBAJAL                  5
# 6                Joz Carlos Gabrillo ORDILLANO                  5
# 7                    Alejandro CEBALLOS JARABA                  4
# 8             Jacqueline Yamileth RIVERA AYALA                  5
# 9                Jean Bosco Alpha MBARUSHIMANA                  4
# 10                        Mercy Wairimu KIMANI                  5
# 11                                 Hnin Ei Mon                  5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
#
#    교육전: A교과에 대한 인지 수준 교육전후 A교과에 대한 인지 수준 변화
# 0                   3                    -1
# 1                   5                     0
# 2                   3                     0
# 3                   5                     0
# 4                   4                     0
# 5                   5                     0
# 6                   5                     0
# 7                   3                     1
# 8                   4                     1
# 9                   2                     2
# 10                  2                     3
# 11                  2                     3
# 12                  2                     3
# Text(0.5, 1.02, '교육전후 A교과에 대한 인지 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '인지 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec89bf5c0>,
#   <matplotlib.axis.YTick at 0x1fec89b6eb8>,
#   <matplotlib.axis.YTick at 0x1fec899aeb8>,
#   <matplotlib.axis.YTick at 0x1fec8a1a780>,
#   <matplotlib.axis.YTick at 0x1fec8a1ac50>,
#   <matplotlib.axis.YTick at 0x1fec8a24198>,
#   <matplotlib.axis.YTick at 0x1fec8a1a6a0>,
#   <matplotlib.axis.YTick at 0x1fec8a1c978>,
#   <matplotlib.axis.YTick at 0x1fec8a0ada0>,
#   <matplotlib.axis.YTick at 0x1fec8a24128>,
#   <matplotlib.axis.YTick at 0x1fec8a24550>,
#   <matplotlib.axis.YTick at 0x1fec8a30198>,
#   <matplotlib.axis.YTick at 0x1fec8a30630>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_cog_a_bef_af_gap))
plt.barh(index, df_cog_a_bef_af_gap['교육전후 A교과에 대한 인지 수준 변화'], align='center', label='교육후 인지 수준 - 교육전 인지 수준')
plt.title('A교과에 대한 인지 수준 변화 \n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('인지 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_cog_a_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
# for i, rect in enumerate(p1):
#     plt.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0,
#          str(df_cog_a_bef_af_gap["교육전: A교과에 대한 인지 수준 변화"][i]),
#          fontsize=15, color='w', ha='right', va='center')

plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'A교과에 대한 인지 수준 변화 \n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '인지 수준 변화 측정값')
# (array([-1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5]),
#  <a list of 11 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec8d96f98>,
#   <matplotlib.axis.YTick at 0x1fec8d96860>,
#   <matplotlib.axis.YTick at 0x1fec6f99e48>,
#   <matplotlib.axis.YTick at 0x1fec8a5f320>,
#   <matplotlib.axis.YTick at 0x1fec8a6f0f0>,
#   <matplotlib.axis.YTick at 0x1fec8a6f860>,
#   <matplotlib.axis.YTick at 0x1fec8a6fd30>,
#   <matplotlib.axis.YTick at 0x1fec8a76240>,
#   <matplotlib.axis.YTick at 0x1fec8a76710>,
#   <matplotlib.axis.YTick at 0x1fec8a76be0>,
#   <matplotlib.axis.YTick at 0x1fec8a7d128>,
#   <matplotlib.axis.YTick at 0x1fec8a76668>,
#   <matplotlib.axis.YTick at 0x1fec8a6fba8>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# #### A교과에 대한 기술 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index


df_tech_a = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: A교과에 대한 기술 수준'],
                           murd_fl['교육전: A교과에 대한 기술 수준'],
                          ],axis=1)

df_tech_a['교육전후 A교과에 대한 기술 수준 변화'] = \
                           murd_fl['교육후: A교과에 대한 기술 수준'] - \
                           murd_fl['교육전: A교과에 대한 기술 수준']

df_tech_a_bef_af_gap = df_tech_a.sort_values(by='교육전후 A교과에 대한 기술 수준 변화',
                            ascending=True).reset_index(drop='index')

df_tech_a_bef_af_gap


plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_tech_a_bef_af_gap))
p1 = plt.barh(index, df_tech_a_bef_af_gap["교육전: A교과에 대한 기술 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_tech_a_bef_af_gap['교육후: A교과에 대한 기술 수준'],  
              align='center', label='Post-Training', left=df_tech_a_bef_af_gap["교육전: A교과에 대한 기술 수준"])

plt.title('교육전후 A교과에 대한 기술 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('기술 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_tech_a_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()
# Out:
#                                             성명 교육후: A교과에 대한 기술 수준  \
# 0                                    Dana PHAL                  2
# 1                    Alejandro CEBALLOS JARABA                  3
# 2             Jacqueline Yamileth RIVERA AYALA                  3
# 3                              Edward AGBODJAN                  3
# 4                      Khin Ohnmar MYINT THEIN                  3
# 5                                  Iqbal AHMED                  5
# 6                          Laura LOZADA ACOSTA                  4
# 7                Joz Carlos Gabrillo ORDILLANO                  5
# 8                                  Hnin Ei Mon                  3
# 9                         Carmen ZANA CARBAJAL                  5
# 10               Jean Bosco Alpha MBARUSHIMANA                  4
# 11                        Mercy Wairimu KIMANI                  5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
#
#    교육전: A교과에 대한 기술 수준 교육전후 A교과에 대한 기술 수준 변화
# 0                   2                     0
# 1                   3                     0
# 2                   3                     0
# 3                   3                     0
# 4                   3                     0
# 5                   5                     0
# 6                   4                     0
# 7                   5                     0
# 8                   2                     1
# 9                   4                     1
# 10                  3                     1
# 11                  2                     3
# 12                  2                     3
# Text(0.5, 1.02, '교육전후 A교과에 대한 기술 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '기술 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec8aba588>,
#   <matplotlib.axis.YTick at 0x1fec8ab5ef0>,
#   <matplotlib.axis.YTick at 0x1fec8ab7ef0>,
#   <matplotlib.axis.YTick at 0x1fec8b17ac8>,
#   <matplotlib.axis.YTick at 0x1fec8b220b8>,
#   <matplotlib.axis.YTick at 0x1fec8b22588>,
#   <matplotlib.axis.YTick at 0x1fec8b17f60>,
#   <matplotlib.axis.YTick at 0x1fec8b185c0>,
#   <matplotlib.axis.YTick at 0x1fec8b17f98>,
#   <matplotlib.axis.YTick at 0x1fec8b22c18>,
#   <matplotlib.axis.YTick at 0x1fec8b2c160>,
#   <matplotlib.axis.YTick at 0x1fec8b2c5f8>,
#   <matplotlib.axis.YTick at 0x1fec8b2cac8>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_tech_a_bef_af_gap))
plt.barh(index, df_tech_a_bef_af_gap['교육전후 A교과에 대한 기술 수준 변화'], align='center', label='교육후 기술 수준 - 교육전 기술 수준')
plt.title('A교과에 대한 기술 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('기술 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_tech_a_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
 
plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'A교과에 대한 기술 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '기술 수준 변화 측정값')
# (array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5]),
#  <a list of 8 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec8b6b400>,
#   <matplotlib.axis.YTick at 0x1fec8b4e828>,
#   <matplotlib.axis.YTick at 0x1fec8aa3da0>,
#   <matplotlib.axis.YTick at 0x1fec8bab278>,
#   <matplotlib.axis.YTick at 0x1fec8bab748>,
#   <matplotlib.axis.YTick at 0x1fec8ba17f0>,
#   <matplotlib.axis.YTick at 0x1fec8b990f0>,
#   <matplotlib.axis.YTick at 0x1fec8bab710>,
#   <matplotlib.axis.YTick at 0x1fec8babda0>,
#   <matplotlib.axis.YTick at 0x1fec8baf2b0>,
#   <matplotlib.axis.YTick at 0x1fec8baf7b8>,
#   <matplotlib.axis.YTick at 0x1fec8bafcc0>,
#   <matplotlib.axis.YTick at 0x1fec8bb91d0>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# #### A교과에 대한 태도 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index


df_atti_a = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: A교과에 대한 태도 수준'],
                           murd_fl['교육전: A교과에 대한 태도 수준'],
                          ],axis=1)

df_atti_a['교육전후 A교과에 대한 태도 수준 변화'] = \
                           murd_fl['교육후: A교과에 대한 태도 수준'] - \
                           murd_fl['교육전: A교과에 대한 태도 수준']

df_atti_a_bef_af_gap = df_atti_a.sort_values(by='교육전후 A교과에 대한 태도 수준 변화',
                            ascending=True).reset_index(drop='index')

df_atti_a_bef_af_gap


plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_atti_a_bef_af_gap))
p1 = plt.barh(index, df_atti_a_bef_af_gap["교육전: A교과에 대한 태도 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_atti_a_bef_af_gap['교육후: A교과에 대한 태도 수준'],  
              align='center', label='Post-Training', left=df_atti_a_bef_af_gap["교육전: A교과에 대한 태도 수준"])

plt.title('교육전후 A교과에 대한 태도 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('태도 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_atti_a_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()
# Out:
#                                             성명 교육후: A교과에 대한 태도 수준  \
# 0                                    Dana PHAL                  2
# 1                    Alejandro CEBALLOS JARABA                  4
# 2             Jacqueline Yamileth RIVERA AYALA                  4
# 3                      Khin Ohnmar MYINT THEIN                  3
# 4                          Laura LOZADA ACOSTA                  4
# 5                         Mercy Wairimu KIMANI                  5
# 6                                  Hnin Ei Mon                  4
# 7                         Carmen ZANA CARBAJAL                  5
# 8                Joz Carlos Gabrillo ORDILLANO                  5
# 9                Jean Bosco Alpha MBARUSHIMANA                  4
# 10                             Edward AGBODJAN                  5
# 11                                 Iqbal AHMED                  5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
#
#    교육전: A교과에 대한 태도 수준 교육전후 A교과에 대한 태도 수준 변화
# 0                   3                    -1
# 1                   5                    -1
# 2                   5                    -1
# 3                   4                    -1
# 4                   5                    -1
# 5                   5                     0
# 6                   4                     0
# 7                   5                     0
# 8                   5                     0
# 9                   4                     0
# 10                  4                     1
# 11                  4                     1
# 12                  4                     1
# Text(0.5, 1.02, '교육전후 A교과에 대한 태도 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '태도 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec6f92400>,
#   <matplotlib.axis.YTick at 0x1fec6f8a978>,
#   <matplotlib.axis.YTick at 0x1fec6f85748>,
#   <matplotlib.axis.YTick at 0x1fec6b23978>,
#   <matplotlib.axis.YTick at 0x1fec889f6a0>,
#   <matplotlib.axis.YTick at 0x1fec889fb38>,
#   <matplotlib.axis.YTick at 0x1fec889feb8>,
#   <matplotlib.axis.YTick at 0x1fec6bb63c8>,
#   <matplotlib.axis.YTick at 0x1fec6bb6898>,
#   <matplotlib.axis.YTick at 0x1fec6bb6d68>,
#   <matplotlib.axis.YTick at 0x1fec8a9a278>,
#   <matplotlib.axis.YTick at 0x1fec8a9a748>,
#   <matplotlib.axis.YTick at 0x1fec6bb6518>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_atti_a_bef_af_gap))

plt.barh(index, df_atti_a_bef_af_gap['교육전후 A교과에 대한 태도 수준 변화'], align='center', label='교육후 태도 수준 - 교육전 태도 수준')
plt.title('A교과에 대한 태도 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('태도 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_atti_a_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
 
plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'A교과에 대한 태도 수준 변화\n(A교과: PPP와 개도국에 대한 PPP적용방법에 대한 이해)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '태도 수준 변화 측정값')
# (array([-1.25, -1.  , -0.75, -0.5 , -0.25,  0.  ,  0.25,  0.5 ,  0.75,
#          1.  ,  1.25]), <a list of 11 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec6f49160>,
#   <matplotlib.axis.YTick at 0x1fec8a888d0>,
#   <matplotlib.axis.YTick at 0x1fec8bd28d0>,
#   <matplotlib.axis.YTick at 0x1fec6e0e0b8>,
#   <matplotlib.axis.YTick at 0x1fec8be45c0>,
#   <matplotlib.axis.YTick at 0x1fec8be4be0>,
#   <matplotlib.axis.YTick at 0x1fec8beb160>,
#   <matplotlib.axis.YTick at 0x1fec8beb5c0>,
#   <matplotlib.axis.YTick at 0x1fec8beba90>,
#   <matplotlib.axis.YTick at 0x1fec8bebf60>,
#   <matplotlib.axis.YTick at 0x1fec8bff470>,
#   <matplotlib.axis.YTick at 0x1fec8beb710>,
#   <matplotlib.axis.YTick at 0x1fec8be4ba8>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# ### '개도국을 위한 적용가능한 수질개선기술 (B교과)'에 대한 참가자별 '인지 - 기술 - 태도' 수준 변화

# %% [markdown]
# #### B교과에 대한 인지 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index

df_cog_b = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: B교과에 대한 인지 수준'],
                           murd_fl['교육전: B교과에 대한 인지 수준']
                          ],axis=1)

df_cog_b['교육전후 B교과에 대한 인지 수준 변화'] = \
                           murd_fl['교육후: B교과에 대한 인지 수준'] - \
                           murd_fl["교육전: B교과에 대한 인지 수준"]

df_cog_b_bef_af_gap = df_cog_b.sort_values(by='교육전후 B교과에 대한 인지 수준 변화',
                            ascending=True).reset_index(drop='index')

df_cog_b_bef_af_gap

plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_cog_b_bef_af_gap))
p1 = plt.barh(index, df_cog_b_bef_af_gap["교육전: B교과에 대한 인지 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_cog_b_bef_af_gap['교육후: B교과에 대한 인지 수준'],  
              align='center', label='Post-Training', left=df_cog_b_bef_af_gap["교육전: B교과에 대한 인지 수준"])

plt.title('교육전후 B교과에 대한 인지 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('인지 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_cog_b_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()

# for i, rect in enumerate(p1):
#     plt.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0,
#          str(df_cog_b_bef_af_gap["교육전: B교과에 대한 인지 수준 변화"][i]),
#          fontsize=15, color='w', ha='right', va='center')
# Out:
#                                             성명 교육후: B교과에 대한 인지 수준  \
# 0             Jacqueline Yamileth RIVERA AYALA                  4
# 1                      Khin Ohnmar MYINT THEIN                  2
# 2                                    Dana PHAL                  2
# 3                                  Iqbal AHMED                  5
# 4                          Laura LOZADA ACOSTA                  4
# 5                         Carmen ZANA CARBAJAL                  5
# 6                Joz Carlos Gabrillo ORDILLANO                  4
# 7                    Alejandro CEBALLOS JARABA                  4
# 8                         Mercy Wairimu KIMANI                  4
# 9                Jean Bosco Alpha MBARUSHIMANA                  4
# 10                             Edward AGBODJAN                  4
# 11                                 Hnin Ei Mon                  5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
#
#    교육전: B교과에 대한 인지 수준 교육전후 B교과에 대한 인지 수준 변화
# 0                   5                    -1
# 1                   3                    -1
# 2                   2                     0
# 3                   5                     0
# 4                   4                     0
# 5                   5                     0
# 6                   4                     0
# 7                   3                     1
# 8                   2                     2
# 9                   2                     2
# 10                  1                     3
# 11                  2                     3
# 12                  1                     4
# Text(0.5, 1.02, '교육전후 B교과에 대한 인지 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '인지 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec6eec8d0>,
#   <matplotlib.axis.YTick at 0x1fec6eec208>,
#   <matplotlib.axis.YTick at 0x1fec6ec4cc0>,
#   <matplotlib.axis.YTick at 0x1fec8c06e48>,
#   <matplotlib.axis.YTick at 0x1fec8c11358>,
#   <matplotlib.axis.YTick at 0x1fec8c11860>,
#   <matplotlib.axis.YTick at 0x1fec8c06978>,
#   <matplotlib.axis.YTick at 0x1fec6e9a4a8>,
#   <matplotlib.axis.YTick at 0x1fec8c11940>,
#   <matplotlib.axis.YTick at 0x1fec8c11f28>,
#   <matplotlib.axis.YTick at 0x1fec8c15470>,
#   <matplotlib.axis.YTick at 0x1fec8c15978>,
#   <matplotlib.axis.YTick at 0x1fec8c15e80>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_cog_b_bef_af_gap))
plt.barh(index, df_cog_b_bef_af_gap['교육전후 B교과에 대한 인지 수준 변화'], align='center', label='교육후 인지 수준 - 교육전 인지 수준')
plt.title('B교과에 대한 인지 수준 변화 \n(B교과: 개도국을 위한 적용가능한 수질개선기술)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('인지 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_cog_b_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
# for i, rect in enumerate(p1):
#     plt.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0,
#          str(df_cog_b_bef_af_gap["교육전: B교과에 대한 인지 수준 변화"][i]),
#          fontsize=15, color='w', ha='right', va='center')

plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'B교과에 대한 인지 수준 변화 \n(B교과: 개도국을 위한 적용가능한 수질개선기술)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '인지 수준 변화 측정값')
# (array([-2., -1.,  0.,  1.,  2.,  3.,  4.,  5.]),
#  <a list of 8 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec8c3b668>,
#   <matplotlib.axis.YTick at 0x1fec81891d0>,
#   <matplotlib.axis.YTick at 0x1fec8c34be0>,
#   <matplotlib.axis.YTick at 0x1fec8c89438>,
#   <matplotlib.axis.YTick at 0x1fec8c838d0>,
#   <matplotlib.axis.YTick at 0x1fec8c7bba8>,
#   <matplotlib.axis.YTick at 0x1fec8c7b7f0>,
#   <matplotlib.axis.YTick at 0x1fec8c89400>,
#   <matplotlib.axis.YTick at 0x1fec8c8e2b0>,
#   <matplotlib.axis.YTick at 0x1fec8c8e780>,
#   <matplotlib.axis.YTick at 0x1fec8c8ec50>,
#   <matplotlib.axis.YTick at 0x1fec8c97198>,
#   <matplotlib.axis.YTick at 0x1fec8c97630>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# #### B교과에 대한 기술 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index


df_tech_b = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: B교과에 대한 기술 수준'],
                           murd_fl['교육전: B교과에 대한 기술 수준'],
                          ],axis=1)

df_tech_b['교육전후 B교과에 대한 기술 수준 변화'] = \
                           murd_fl['교육후: B교과에 대한 기술 수준'] - \
                           murd_fl['교육전: B교과에 대한 기술 수준']

df_tech_b_bef_af_gap = df_tech_b.sort_values(by='교육전후 B교과에 대한 기술 수준 변화',
                            ascending=True).reset_index(drop='index')

df_tech_b_bef_af_gap


plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_tech_b_bef_af_gap))
p1 = plt.barh(index, df_tech_b_bef_af_gap["교육전: B교과에 대한 기술 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_tech_b_bef_af_gap['교육후: B교과에 대한 기술 수준'],  
              align='center', label='Post-Training', left=df_tech_b_bef_af_gap["교육전: B교과에 대한 기술 수준"])

plt.title('교육전후 B교과에 대한 기술 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('기술 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_tech_b_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()
# Out:
#                                             성명 교육후: B교과에 대한 기술 수준  \
# 0             Jacqueline Yamileth RIVERA AYALA                  3
# 1                Joz Carlos Gabrillo ORDILLANO                  3
# 2                      Khin Ohnmar MYINT THEIN                  2
# 3                                    Dana PHAL                  1
# 4                    Alejandro CEBALLOS JARABA                  3
# 5                              Edward AGBODJAN                  3
# 6                                  Iqbal AHMED                  5
# 7                          Laura LOZADA ACOSTA                  4
# 8                         Carmen ZANA CARBAJAL                  5
# 9                Jean Bosco Alpha MBARUSHIMANA                  4
# 10                        Mercy Wairimu KIMANI                  4
# 11                                 Hnin Ei Mon                  3
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  4
#
#    교육전: B교과에 대한 기술 수준 교육전후 B교과에 대한 기술 수준 변화
# 0                   5                    -2
# 1                   5                    -2
# 2                   3                    -1
# 3                   1                     0
# 4                   3                     0
# 5                   3                     0
# 6                   5                     0
# 7                   3                     1
# 8                   4                     1
# 9                   3                     1
# 10                  2                     2
# 11                  1                     2
# 12                  1                     3
# Text(0.5, 1.02, '교육전후 B교과에 대한 기술 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '기술 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec8cd5f28>,
#   <matplotlib.axis.YTick at 0x1fec8cd5828>,
#   <matplotlib.axis.YTick at 0x1fec8cd1828>,
#   <matplotlib.axis.YTick at 0x1fec8d264a8>,
#   <matplotlib.axis.YTick at 0x1fec8d269b0>,
#   <matplotlib.axis.YTick at 0x1fec8d26e80>,
#   <matplotlib.axis.YTick at 0x1fec8d26978>,
#   <matplotlib.axis.YTick at 0x1fec8d20a90>,
#   <matplotlib.axis.YTick at 0x1fec8d16c88>,
#   <matplotlib.axis.YTick at 0x1fec8d2e160>,
#   <matplotlib.axis.YTick at 0x1fec8d2e9b0>,
#   <matplotlib.axis.YTick at 0x1fec8d2ee80>,
#   <matplotlib.axis.YTick at 0x1fec8d35390>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_tech_b_bef_af_gap))
plt.barh(index, df_tech_b_bef_af_gap['교육전후 B교과에 대한 기술 수준 변화'], align='center', label='교육후 기술 수준 - 교육전 기술 수준')
plt.title('B교과에 대한 기술 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('기술 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_tech_b_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
 
plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'B교과에 대한 기술 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '기술 수준 변화 측정값')
# (array([-3., -2., -1.,  0.,  1.,  2.,  3.,  4.]),
#  <a list of 8 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec8d58cc0>,
#   <matplotlib.axis.YTick at 0x1fec8d581d0>,
#   <matplotlib.axis.YTick at 0x1fec8c28630>,
#   <matplotlib.axis.YTick at 0x1fec9126c18>,
#   <matplotlib.axis.YTick at 0x1fec9126b70>,
#   <matplotlib.axis.YTick at 0x1fec911fba8>,
#   <matplotlib.axis.YTick at 0x1fec9116748>,
#   <matplotlib.axis.YTick at 0x1fec912c320>,
#   <matplotlib.axis.YTick at 0x1fec912c940>,
#   <matplotlib.axis.YTick at 0x1fec912ce10>,
#   <matplotlib.axis.YTick at 0x1fec9134320>,
#   <matplotlib.axis.YTick at 0x1fec91347f0>,
#   <matplotlib.axis.YTick at 0x1fec9134cc0>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# #### B교과에 대한 태도 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index


df_atti_b = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: B교과에 대한 태도 수준'],
                           murd_fl['교육전: B교과에 대한 태도 수준'],
                          ],axis=1)

df_atti_b['교육전후 B교과에 대한 태도 수준 변화'] = \
                           murd_fl['교육후: B교과에 대한 태도 수준'] - \
                           murd_fl['교육전: B교과에 대한 태도 수준']

df_atti_b_bef_af_gap = df_atti_b.sort_values(by='교육전후 B교과에 대한 태도 수준 변화',
                            ascending=True).reset_index(drop='index')

df_atti_b_bef_af_gap


plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_atti_b_bef_af_gap))
p1 = plt.barh(index, df_atti_b_bef_af_gap["교육전: B교과에 대한 태도 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_atti_b_bef_af_gap['교육후: B교과에 대한 태도 수준'],  
              align='center', label='Post-Training', left=df_atti_b_bef_af_gap["교육전: B교과에 대한 태도 수준"])

plt.title('교육전후 B교과에 대한 태도 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('태도 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_atti_b_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()
# Out:
#                                             성명 교육후: B교과에 대한 태도 수준  \
# 0                      Khin Ohnmar MYINT THEIN                  1
# 1             Jacqueline Yamileth RIVERA AYALA                  4
# 2                         Mercy Wairimu KIMANI                  4
# 3                                    Dana PHAL                  2
# 4                    Alejandro CEBALLOS JARABA                  4
# 5                          Laura LOZADA ACOSTA                  4
# 6                         Carmen ZANA CARBAJAL                  5
# 7                Joz Carlos Gabrillo ORDILLANO                  4
# 8                Jean Bosco Alpha MBARUSHIMANA                  4
# 9                              Edward AGBODJAN                  3
# 10                                 Hnin Ei Mon                  4
# 11                                 Iqbal AHMED                  5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  4
#
#    교육전: B교과에 대한 태도 수준 교육전후 B교과에 대한 태도 수준 변화
# 0                   3                    -2
# 1                   5                    -1
# 2                   5                    -1
# 3                   2                     0
# 4                   4                     0
# 5                   4                     0
# 6                   5                     0
# 7                   4                     0
# 8                   4                     0
# 9                   2                     1
# 10                  3                     1
# 11                  4                     1
# 12                  2                     2
# Text(0.5, 1.02, '교육전후 B교과에 대한 태도 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '태도 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec916a6a0>,
#   <matplotlib.axis.YTick at 0x1fec9170f60>,
#   <matplotlib.axis.YTick at 0x1fec916eef0>,
#   <matplotlib.axis.YTick at 0x1fec91d1b70>,
#   <matplotlib.axis.YTick at 0x1fec91d8128>,
#   <matplotlib.axis.YTick at 0x1fec91d8550>,
#   <matplotlib.axis.YTick at 0x1fec91d1940>,
#   <matplotlib.axis.YTick at 0x1fec91cd080>,
#   <matplotlib.axis.YTick at 0x1fec91d84a8>,
#   <matplotlib.axis.YTick at 0x1fec91d8be0>,
#   <matplotlib.axis.YTick at 0x1fec91e2160>,
#   <matplotlib.axis.YTick at 0x1fec91e2630>,
#   <matplotlib.axis.YTick at 0x1fec91e2b00>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_atti_b_bef_af_gap))

plt.barh(index, df_atti_b_bef_af_gap['교육전후 B교과에 대한 태도 수준 변화'], align='center', label='교육후 태도 수준 - 교육전 태도 수준')
plt.title('B교과에 대한 태도 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('태도 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_atti_b_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
 
plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'B교과에 대한 태도 수준 변화\n(B교과: 개도국을 위한 적용가능한 수질개선기술)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '태도 수준 변화 측정값')
# (array([-2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5]),
#  <a list of 11 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec9216400>,
#   <matplotlib.axis.YTick at 0x1fec9205be0>,
#   <matplotlib.axis.YTick at 0x1fec9145b00>,
#   <matplotlib.axis.YTick at 0x1fec92524a8>,
#   <matplotlib.axis.YTick at 0x1fec9260518>,
#   <matplotlib.axis.YTick at 0x1fec9260eb8>,
#   <matplotlib.axis.YTick at 0x1fec9268400>,
#   <matplotlib.axis.YTick at 0x1fec9268908>,
#   <matplotlib.axis.YTick at 0x1fec9268e10>,
#   <matplotlib.axis.YTick at 0x1fec926f358>,
#   <matplotlib.axis.YTick at 0x1fec926f860>,
#   <matplotlib.axis.YTick at 0x1fec92684a8>,
#   <matplotlib.axis.YTick at 0x1fec9260748>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# ### '개도국을 위한 미디어시티, 도로, 교통시설 개발 (C 교과)' 에 대한 참가자별 '인지 - 기술 - 태도' 수준 변화

# %% [markdown]
# #### C교과에 대한 인지 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index

df_cog_c = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: C교과에 대한 인지 수준'],
                           murd_fl['교육전: C교과에 대한 인지 수준']
                          ],axis=1)

df_cog_c['교육전후 C교과에 대한 인지 수준 변화'] = \
                           murd_fl['교육후: C교과에 대한 인지 수준'] - \
                           murd_fl["교육전: C교과에 대한 인지 수준"]

df_cog_c_bef_af_gap = df_cog_c.sort_values(by='교육전후 C교과에 대한 인지 수준 변화',
                            ascending=True).reset_index(drop='index')

df_cog_c_bef_af_gap

plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_cog_c_bef_af_gap))
p1 = plt.barh(index, df_cog_c_bef_af_gap["교육전: C교과에 대한 인지 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_cog_c_bef_af_gap['교육후: C교과에 대한 인지 수준'],  
              align='center', label='Post-Training', left=df_cog_c_bef_af_gap["교육전: C교과에 대한 인지 수준"])

plt.title('교육전후 C교과에 대한 인지 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('인지 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_cog_c_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()

# for i, rect in enumerate(p1):
#     plt.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0,
#          str(df_cog_c_bef_af_gap["교육전: C교과에 대한 인지 수준 변화"][i]),
#          fontsize=15, color='w', ha='right', va='center')
# Out:
#                                             성명 교육후: C교과에 대한 인지 수준  \
# 0             Jacqueline Yamileth RIVERA AYALA                  3
# 1                Joz Carlos Gabrillo ORDILLANO                  4
# 2                      Khin Ohnmar MYINT THEIN                  3
# 3                                  Iqbal AHMED                  5
# 4                          Laura LOZADA ACOSTA                  3
# 5                         Carmen ZANA CARBAJAL                  5
# 6                                    Dana PHAL                  3
# 7                              Edward AGBODJAN                  5
# 8                Jean Bosco Alpha MBARUSHIMANA                  3
# 9                         Mercy Wairimu KIMANI                  4
# 10                                 Hnin Ei Mon                  4
# 11                   Alejandro CEBALLOS JARABA                  5
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
#
#    교육전: C교과에 대한 인지 수준 교육전후 C교과에 대한 인지 수준 변화
# 0                   4                    -1
# 1                   5                    -1
# 2                   3                     0
# 3                   5                     0
# 4                   3                     0
# 5                   5                     0
# 6                   2                     1
# 7                   4                     1
# 8                   2                     1
# 9                   2                     2
# 10                  2                     2
# 11                  2                     3
# 12                  2                     3
# Text(0.5, 1.02, '교육전후 C교과에 대한 인지 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '인지 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec92aac18>,
#   <matplotlib.axis.YTick at 0x1fec92aa550>,
#   <matplotlib.axis.YTick at 0x1fec92b14e0>,
#   <matplotlib.axis.YTick at 0x1fec9310fd0>,
#   <matplotlib.axis.YTick at 0x1fec93165f8>,
#   <matplotlib.axis.YTick at 0x1fec9316ac8>,
#   <matplotlib.axis.YTick at 0x1fec9316e80>,
#   <matplotlib.axis.YTick at 0x1fec9310ba8>,
#   <matplotlib.axis.YTick at 0x1fec9304c18>,
#   <matplotlib.axis.YTick at 0x1fec9317160>,
#   <matplotlib.axis.YTick at 0x1fec93175f8>,
#   <matplotlib.axis.YTick at 0x1fec9317ac8>,
#   <matplotlib.axis.YTick at 0x1fec9317e80>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_cog_c_bef_af_gap))
plt.barh(index, df_cog_c_bef_af_gap['교육전후 C교과에 대한 인지 수준 변화'], align='center', label='교육후 인지 수준 - 교육전 인지 수준')
plt.title('C교과에 대한 인지 수준 변화 \n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('인지 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_cog_c_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
# for i, rect in enumerate(p1):
#     plt.text(0.95 * rect.get_width(), rect.get_y() + rect.get_height() / 2.0,
#          str(df_cog_c_bef_af_gap["교육전: C교과에 대한 인지 수준 변화"][i]),
#          fontsize=15, color='w', ha='right', va='center')

plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'C교과에 대한 인지 수준 변화 \n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '인지 수준 변화 측정값')
# (array([-1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5,  3. ,  3.5]),
#  <a list of 11 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec93638d0>,
#   <matplotlib.axis.YTick at 0x1fec9363198>,
#   <matplotlib.axis.YTick at 0x1fec927bb70>,
#   <matplotlib.axis.YTick at 0x1fec93906d8>,
#   <matplotlib.axis.YTick at 0x1fec939d208>,
#   <matplotlib.axis.YTick at 0x1fec93a8400>,
#   <matplotlib.axis.YTick at 0x1fec93a86a0>,
#   <matplotlib.axis.YTick at 0x1fec93a8dd8>,
#   <matplotlib.axis.YTick at 0x1fec93ae2e8>,
#   <matplotlib.axis.YTick at 0x1fec93ae7f0>,
#   <matplotlib.axis.YTick at 0x1fec93aeba8>,
#   <matplotlib.axis.YTick at 0x1fec93aeda0>,
#   <matplotlib.axis.YTick at 0x1fec93a89e8>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# #### C교과에 대한 기술 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index


df_tech_c = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: C교과에 대한 기술 수준'],
                           murd_fl['교육전: C교과에 대한 기술 수준'],
                          ],axis=1)

df_tech_c['교육전후 C교과에 대한 기술 수준 변화'] = \
                           murd_fl['교육후: C교과에 대한 기술 수준'] - \
                           murd_fl['교육전: C교과에 대한 기술 수준']

df_tech_c_bef_af_gap = df_tech_c.sort_values(by='교육전후 C교과에 대한 기술 수준 변화',
                            ascending=True).reset_index(drop='index')

df_tech_c_bef_af_gap


plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_tech_c_bef_af_gap))
p1 = plt.barh(index, df_tech_c_bef_af_gap["교육전: C교과에 대한 기술 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_tech_c_bef_af_gap['교육후: C교과에 대한 기술 수준'],  
              align='center', label='Post-Training', left=df_tech_c_bef_af_gap["교육전: C교과에 대한 기술 수준"])

plt.title('교육전후 C교과에 대한 기술 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('기술 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_tech_c_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()
# Out:
#                                             성명 교육후: C교과에 대한 기술 수준  \
# 0             Jacqueline Yamileth RIVERA AYALA                  3
# 1                Joz Carlos Gabrillo ORDILLANO                  3
# 2                    Alejandro CEBALLOS JARABA                  4
# 3                              Edward AGBODJAN                  3
# 4                      Khin Ohnmar MYINT THEIN                  3
# 5                                  Iqbal AHMED                  5
# 6                          Laura LOZADA ACOSTA                  3
# 7                                    Dana PHAL                  3
# 8                                  Hnin Ei Mon                  3
# 9                         Carmen ZANA CARBAJAL                  5
# 10               Jean Bosco Alpha MBARUSHIMANA                  4
# 11                        Mercy Wairimu KIMANI                  4
# 12  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
#
#    교육전: C교과에 대한 기술 수준 교육전후 C교과에 대한 기술 수준 변화
# 0                   5                    -2
# 1                   5                    -2
# 2                   4                     0
# 3                   3                     0
# 4                   3                     0
# 5                   5                     0
# 6                   3                     0
# 7                   2                     1
# 8                   2                     1
# 9                   4                     1
# 10                  3                     1
# 11                  2                     2
# 12                  2                     3
# Text(0.5, 1.02, '교육전후 C교과에 대한 기술 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '기술 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec93ef198>,
#   <matplotlib.axis.YTick at 0x1fec93f9a90>,
#   <matplotlib.axis.YTick at 0x1fec93f1a90>,
#   <matplotlib.axis.YTick at 0x1fecae84828>,
#   <matplotlib.axis.YTick at 0x1fecae84c88>,
#   <matplotlib.axis.YTick at 0x1fecae7cb70>,
#   <matplotlib.axis.YTick at 0x1fecae717b8>,
#   <matplotlib.axis.YTick at 0x1fecae8b208>,
#   <matplotlib.axis.YTick at 0x1fecae8b6d8>,
#   <matplotlib.axis.YTick at 0x1fecae8bba8>,
#   <matplotlib.axis.YTick at 0x1fecae93128>,
#   <matplotlib.axis.YTick at 0x1fecae93588>,
#   <matplotlib.axis.YTick at 0x1fecae8ba20>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_tech_c_bef_af_gap))
plt.barh(index, df_tech_c_bef_af_gap['교육전후 C교과에 대한 기술 수준 변화'], align='center', label='교육후 기술 수준 - 교육전 기술 수준')
plt.title('C교과에 대한 기술 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('기술 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_tech_c_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
 
plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'C교과에 대한 기술 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '기술 수준 변화 측정값')
# (array([-3., -2., -1.,  0.,  1.,  2.,  3.,  4.]),
#  <a list of 8 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fec93b9fd0>,
#   <matplotlib.axis.YTick at 0x1fecaeaaf98>,
#   <matplotlib.axis.YTick at 0x1fec93c4390>,
#   <matplotlib.axis.YTick at 0x1fecaef9748>,
#   <matplotlib.axis.YTick at 0x1fecaef9ba8>,
#   <matplotlib.axis.YTick at 0x1fecaf01128>,
#   <matplotlib.axis.YTick at 0x1fecaf01588>,
#   <matplotlib.axis.YTick at 0x1fecaf01a58>,
#   <matplotlib.axis.YTick at 0x1fecaf01f28>,
#   <matplotlib.axis.YTick at 0x1fecaf018d0>,
#   <matplotlib.axis.YTick at 0x1fecaef9b70>,
#   <matplotlib.axis.YTick at 0x1fecaf0a358>,
#   <matplotlib.axis.YTick at 0x1fecaf0a8d0>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# #### C교과에 대한 태도 수준 변화

# %%
# '교육전 전반적 이해 수준 변화 수준의 오름차순'으로 정렬 된 '교육전후 전반적 이해 수준 변화 수준'과 'Name'열로 된 DataFrame으로  
# 각각 'Name'  '교육전 전반적 이해 수준 변화 수준' 데이터프레임을 .concat한 후 이를 오름차순. 그 후 reset_index


df_atti_c = pd.concat([murd_fl['성명'],
                           murd_fl['교육후: C교과에 대한 태도 수준'],
                           murd_fl['교육전: C교과에 대한 태도 수준'],
                          ],axis=1)

df_atti_c['교육전후 C교과에 대한 태도 수준 변화'] = \
                           murd_fl['교육후: C교과에 대한 태도 수준'] - \
                           murd_fl['교육전: C교과에 대한 태도 수준']

df_atti_c_bef_af_gap = df_atti_c.sort_values(by='교육전후 C교과에 대한 태도 수준 변화',
                            ascending=True).reset_index(drop='index')

df_atti_c_bef_af_gap


plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_atti_c_bef_af_gap))
p1 = plt.barh(index, df_atti_c_bef_af_gap["교육전: C교과에 대한 태도 수준"],  
              align='center', label='Pre-Training')
p2 = plt.barh(index, df_atti_c_bef_af_gap['교육후: C교과에 대한 태도 수준'],  
              align='center', label='Post-Training', left=df_atti_c_bef_af_gap["교육전: C교과에 대한 태도 수준"])

plt.title('교육전후 C교과에 대한 태도 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('태도 수준', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_atti_c_bef_af_gap['성명'], fontsize=15)
plt.legend((p1[0], p2[0]), ('Pre-Training', 'Post-Training'), fontsize=18)
plt.show()
# Out:
#                                             성명 교육후: C교과에 대한 태도 수준  \
# 0                Joz Carlos Gabrillo ORDILLANO                  3
# 1                    Alejandro CEBALLOS JARABA                  4
# 2             Jacqueline Yamileth RIVERA AYALA                  3
# 3                         Mercy Wairimu KIMANI                  4
# 4                                    Dana PHAL                  3
# 5                      Khin Ohnmar MYINT THEIN                  3
# 6                                  Hnin Ei Mon                  4
# 7                                  Iqbal AHMED                  4
# 8                          Laura LOZADA ACOSTA                  4
# 9                         Carmen ZANA CARBAJAL                  5
# 10  Peeter Hewage Chinthaka Sampath RATHNASIRI                  5
# 11                             Edward AGBODJAN                  5
# 12               Jean Bosco Alpha MBARUSHIMANA                  4
#
#    교육전: C교과에 대한 태도 수준 교육전후 C교과에 대한 태도 수준 변화
# 0                   5                    -2
# 1                   5                    -1
# 2                   4                    -1
# 3                   5                    -1
# 4                   3                     0
# 5                   3                     0
# 6                   4                     0
# 7                   4                     0
# 8                   4                     0
# 9                   5                     0
# 10                  4                     1
# 11                  3                     2
# 12                  2                     2
# Text(0.5, 1.02, '교육전후 C교과에 대한 태도 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '태도 수준')
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12.]),
#  <a list of 7 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fecaf427f0>,
#   <matplotlib.axis.YTick at 0x1fecaf42128>,
#   <matplotlib.axis.YTick at 0x1fecaf40be0>,
#   <matplotlib.axis.YTick at 0x1fecafa8d30>,
#   <matplotlib.axis.YTick at 0x1fecafb0278>,
#   <matplotlib.axis.YTick at 0x1fecafb0748>,
#   <matplotlib.axis.YTick at 0x1fecafa8630>,
#   <matplotlib.axis.YTick at 0x1fecafa39b0>,
#   <matplotlib.axis.YTick at 0x1fecafb0c18>,
#   <matplotlib.axis.YTick at 0x1fecafb0d68>,
#   <matplotlib.axis.YTick at 0x1fecafb9278>,
#   <matplotlib.axis.YTick at 0x1fecafb9748>,
#   <matplotlib.axis.YTick at 0x1fecafb9c18>],
#  <a list of 13 Text yticklabel objects>)

# %%
plt.figure(figsize=(16, 10))
# height = 0.35
index=np.arange(len(df_atti_c_bef_af_gap))

plt.barh(index, df_atti_c_bef_af_gap['교육전후 C교과에 대한 태도 수준 변화'], align='center', label='교육후 태도 수준 - 교육전 태도 수준')
plt.title('C교과에 대한 태도 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)',
          position=(0.5,1.02), fontsize=20)
plt.ylabel('성명', fontsize=18)
plt.xlabel('태도 수준 변화 측정값', fontsize=18)
plt.xticks(fontsize=15)
plt.yticks(index, df_atti_c_bef_af_gap['성명'], fontsize=15)
plt.legend(fontsize=18)
 
plt.show()
# Out:
# <BarContainer object of 13 artists>
# Text(0.5, 1.02, 'C교과에 대한 태도 수준 변화\n(C교과: 개도국을 위한 미디어시티, 도로, 교통시설 개발)')
# Text(0, 0.5, '성명')
# Text(0.5, 0, '태도 수준 변화 측정값')
# (array([-2.5, -2. , -1.5, -1. , -0.5,  0. ,  0.5,  1. ,  1.5,  2. ,  2.5]),
#  <a list of 11 Text xticklabel objects>)
# ([<matplotlib.axis.YTick at 0x1fecafec668>,
#   <matplotlib.axis.YTick at 0x1fecaf89898>,
#   <matplotlib.axis.YTick at 0x1fecafd8518>,
#   <matplotlib.axis.YTick at 0x1fecb023320>,
#   <matplotlib.axis.YTick at 0x1fecb032400>,
#   <matplotlib.axis.YTick at 0x1fecb03c128>,
#   <matplotlib.axis.YTick at 0x1fecb03c588>,
#   <matplotlib.axis.YTick at 0x1fecb03ca58>,
#   <matplotlib.axis.YTick at 0x1fecb03cf28>,
#   <matplotlib.axis.YTick at 0x1fecb044438>,
#   <matplotlib.axis.YTick at 0x1fecb044908>,
#   <matplotlib.axis.YTick at 0x1fecb044dd8>,
#   <matplotlib.axis.YTick at 0x1fecb0444e0>],
#  <a list of 13 Text yticklabel objects>)

# %% [markdown]
# ### 교육전후 교과별 '인지 수준 - 기술 수준 - 태도 수준' 변화의 합

# %%
murd_fl.columns.values
# Out:
# array(['성명', '국가명', '기관', '직책', '근무연수', '생년', '성별_x',
#        '연수생 선발/추천을 위한 사전준비 기간은 적절하였다', '연수 신청방법 및 교육내용에 대한 구체적인 안내를 받았다.',
#        '교육전: A교과에 대한 인지 수준', '교육전: A교과에 대한 기술 수준', '교육전: A교과에 대한 태도 수준',
#        '교육전: B교과에 대한 인지 수준', '교육전: B교과에 대한 기술 수준', '교육전: B교과에 대한 태도 수준',
#        '교육전: C교과에 대한 인지 수준', '교육전: C교과에 대한 기술 수준', '교육전: C교과에 대한 태도 수준',
#        '연수과정의 내용은 연수생 현지의 상황과 요구에 맞게 구성되었다.', '연수과정의 내용과 수준은 이해하기 적절하였다.',
#        '연수과정의 교육방법(강의, 실습/토의, 현장학습 등)은 연수내용을 이해하는데 적합하였다.',
#        '연수기관에서는 연수생 국가의 문화나 종교를 배려하기 위해 노력하였다',
#        '연수운영진은 연수과정을 원활하게 운영하였다. (일정관리, 강의준비, 연수생 지원 등)',
#        '연수운영진은 응급상황 등 사건사고에 대해 적절히 대처하였다.', '강의실 및 실습실은 사용하기에 편리하였다.',
#        '연수 편의시설(휴게시설, 식당, 숙박시설 등)은 사용하기에 편리하였다. ',
#        '귀하께서 참여하신 연수과정에 통역사가 있었습니까?',
#        '연수과정에 사용된 교수학습매체는 적절하였다. (교재, 동영상, 실습장비 등)',
#        '강사진은 해당 분야에 대한 실무경험이나 전문성 수준이 높은 인력으로 구성되었다.',
#        '강사는 연수생과 소통하며 교육내용을 체계적이고 능숙하게 전달하였다',
#        '통역사는 이해하기 쉽도록 통역하였다. (2-1에서 ②에 응답한 경우, 응답하지 않으셔도 됩니다)',
#        '교육후: A교과에 대한 인지 수준', '교육후: A교과에 대한 기술 수준', '교육후: A교과에 대한 태도 수준',
#        '교육후: B교과에 대한 인지 수준', '교육후: B교과에 대한 기술 수준', '교육후: B교과에 대한 태도 수준',
#        '교육후: C교과에 대한 인지 수준', '교육후: C교과에 대한 기술 수준', '교육후: C교과에 대한 태도 수준',
#        '국별보고/액션플랜의 주제는 연수과정 목표와 연계되어 있었다.', '국별보고/액션플랜 세션시간은 충분하였다.',
#        '액션플랜 작성 및 발표를 위한 사전안내가 충분히 이루어졌다.',
#        '국별보고/액션플랜 세션 담당자는 피드백을 충분히 제공하였다.',
#        '국별보고/액션플랜 세션은 연수내용을 이해하는데 도움이 되었다.',
#        '액션플랜 작성은 현장에서 실무능력을 향상시키는데 도움이 되었다.', '학번', '전공', '수', '참가기간(시작)',
#        '참가기간(종료)', '체류기간(시작)', '체류기간(종료)', '성명_국문', '대륙', '대륙_국문', '대륙2',
#        '대륙2_국문', '국가', '국가_국문', '도시', '도시_국문', '기관분류', '생년월일', '주민번호',
#        '성별_y', '소속', '직위', '자국내 주소', '이메일', '연락처(자국)', '핸드폰', '기숙사번호',
#        '포털아이디', '비번', '학적', '학적2', '졸업일', '은행', '계좌', '계좌주', '외국인등록증 만료일',
#        '기피음식', '대표', '세부전공', '총평균평점', '논문제목', '지도교수', '인턴십', '인턴십_국문',
#        '배치부서', '인턴십 기간(시작)', '인턴십 기간(종료)', '인턴십 비고', '인턴십2', '인턴십_국문2',
#        '배치부서2', '인턴십 기간2(시작)', '인턴십 기간2(종료)', '인턴십 비고2', '인턴십3',
#        '인턴십_국문3', '배치부서3', '인턴십 기간3(시작)', '인턴십 기간3(종료)', '인턴십 비고3',
#        '국외여행1-1', '국외여행1-2', '행선지1', '국외여행일수1', '국외여행2-1', '국외여행2-2',
#        '행선지2', '국외여행일수2', '국외여행3-1', '국외여행3-2', '행선지3', '국외여행일수3',
#        '국외여행4-1', '국외여행4-2', '행선지4', '국외여행일수4', '국외여행합계', '논문분야', '논문평점',
#        '소속분류', '소속분류2', '소속분류3', '소속분류_Kor', '소속분류2_Kor', '소속분류3_Kor'],
#       dtype=object)

# %%
gb = murd_fl.groupby('소속분류_Kor')
gb.get_group('주택과 지역사회 개발').set_index('성명')[['근무연수','생년','성별_x']]
# Out:
#                           근무연수    생년 성별_x
# 성명
# Alejandro CEBALLOS JARABA    5  1987    남
# Mercy Wairimu KIMANI        13  1976    여

# %%
murd_fl2 = murd_fl.copy()['연수과정의 내용과 수준은 이해하기 적절하였다.'].astype("float")

# %%
murd_fl2.head()
# Out:
# 0    3.0
# 1    5.0
# 2    5.0
# 3    5.0
# 4    5.0
# Name: 연수과정의 내용과 수준은 이해하기 적절하였다., dtype: float64

# %%
murd_fl2.groupby(murd_fl2['소속분류_Kor'])['연수과정의 내용과 수준은 이해하기 적절하였다.']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-123-a668bd972b55> in <module>
# ----> 1 murd_fl2.groupby(murd_fl2['소속분류_Kor'])['연수과정의 내용과 수준은 이해하기 적절하였다.']
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# C:\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3116         try:
#    3117             return self._engine.get_value(s, k,
# -> 3118                                           tz=getattr(series.dtype, 'tz', None))
#    3119         except KeyError as e1:
#    3120             if len(self) > 0 and self.inferred_type in ['integer', 'boolean']:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: '소속분류_Kor'
